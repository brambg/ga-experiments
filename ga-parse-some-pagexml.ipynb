# %%
import glob
import nltk
import random

from collections import Counter

from pagexml.parser import parse_pagexml_file
from pagexml.model.physical_document_model import pretty_print_textregion

data_dir='../pagexml'
scan_dirs = glob.glob(f'{data_dir}/*[0-9]')

def scan_paths(scan_dir:str):
    return glob.glob(f'{scan_dir}/*.xml')

# %%
len(scan_dirs)
# Out:
# 722

# %%
dir=scan_dirs[random.randint(0,len(scan_dirs))]
paths = scan_paths(dir)

# %%
import concurrent.futures

# %% [markdown]
# ## parse the pagexml with multiple processes

# %%
# %%time
print(f'Parsing {len(paths)} scans in directory {dir}')
with concurrent.futures.ProcessPoolExecutor() as executor:
    scans = list(executor.map(parse_pagexml_file, paths))
print()
print(len(scans))
scans[0].metadata
# Out:
# Parsing 245 scans in directory ../pagexml/2386_NOTD00254
#
# 245
# CPU times: user 812 ms, sys: 357 ms, total: 1.17 s
# Wall time: 2.43 s
# {'Creator': 'Transkribus',
#  'Created': datetime.datetime(2020, 12, 8, 13, 40, 18, 321000, tzinfo=tzoffset(None, 3600)),
#  'LastChange': datetime.datetime(2020, 12, 8, 13, 40, 23, 439000, tzinfo=tzoffset(None, 3600)),
#  'filename': '../pagexml/2386_NOTD00254/NOTD00254000001.xml'}

# %% [markdown]
# ## parse the pagexml with multiple threads

# %%
# %%time
print(f'Parsing {len(paths)} scans in directory {dir}')
with concurrent.futures.ThreadPoolExecutor() as executor:
    scans = list(executor.map(parse_pagexml_file, paths))
print()
print(len(scans))
scans[0].metadata
# Out:
# Parsing 245 scans in directory ../pagexml/2386_NOTD00254
#
# 245
# CPU times: user 2.16 s, sys: 337 ms, total: 2.5 s
# Wall time: 2.21 s
# {'Creator': 'Transkribus',
#  'Created': datetime.datetime(2020, 12, 8, 13, 40, 18, 321000, tzinfo=tzoffset(None, 3600)),
#  'LastChange': datetime.datetime(2020, 12, 8, 13, 40, 23, 439000, tzinfo=tzoffset(None, 3600)),
#  'filename': '../pagexml/2386_NOTD00254/NOTD00254000001.xml'}

# %% [markdown]
# ## parse the pagexml sequentially

# %%
# %%time
print(f'Parsing {len(paths)} scans in directory {dir}')
scans = [parse_pagexml_file(p) for p in paths]
print()
print(len(scans))
scans[0].metadata
# Out:
# Parsing 245 scans in directory ../pagexml/2386_NOTD00254
#
# 245
# CPU times: user 2.01 s, sys: 151 ms, total: 2.16 s
# Wall time: 3.03 s
# {'Creator': 'Transkribus',
#  'Created': datetime.datetime(2020, 12, 8, 13, 40, 18, 321000, tzinfo=tzoffset(None, 3600)),
#  'LastChange': datetime.datetime(2020, 12, 8, 13, 40, 23, 439000, tzinfo=tzoffset(None, 3600)),
#  'filename': '../pagexml/2386_NOTD00254/NOTD00254000001.xml'}

# %%
scans[0].metadata
# Out:
# {'Creator': 'Transkribus',
#  'Created': datetime.datetime(2020, 12, 8, 13, 40, 18, 321000, tzinfo=tzoffset(None, 3600)),
#  'LastChange': datetime.datetime(2020, 12, 8, 13, 40, 23, 439000, tzinfo=tzoffset(None, 3600)),
#  'filename': '../pagexml/2386_NOTD00254/NOTD00254000001.xml'}

# %%
Counter([scan.main_type for scan in scans]).most_common()
# Out:
# [('scan', 245)]

# %%
Counter([scan.id for scan in scans]).most_common()
# Out:
# [(None, 245)]

# %%
Counter([scan.parent for scan in scans]).most_common()
# Out:
# [(None, 245)]

# %%
Counter([scan.orientation for scan in scans]).most_common()
# Out:
# [(None, 245)]

# %%
words = [w for scan in scans for w in scan.get_words()]
len(words)
lwords =[w.lower() for w in words]

# %%
bc = Counter([b for b in nltk.bigrams(lwords)])
bc.most_common()
# Out:
# [(('winter', 'n.p.'), 105),
#  (('mits', 'desen'), 102),
#  (('de', 'winter'), 101),
#  (('van', 'hen'), 90),
#  (('van', 'jan'), 86),
#  (('voor', 'mij'), 84),
#  (('binnen', 'deser'), 84),
#  (('soude', 'mogen'), 84),
#  (('j:de', 'winter'), 83),
#  (('de', 'voorsz.'), 78),
#  (('mij', 'notario'), 74),
#  (('dat', 'alle'), 71),
#  (('binnen', 'amstelredamme'), 70),
#  (('mij', 'jacob'), 68),
#  (('caroli', 'guldens'), 68),
#  (('somme', 'van'), 66),
#  (('die', 'sij'), 66),
#  (('getuijgen', 'hier'), 59),
#  (('jacob', 'de'), 58),
#  (('de', 'somme'), 56),
#  (('ende', 'dat'), 53),
#  (('gedaen', 'binnen'), 53),
#  (('te', 'mogen'), 52),
#  (('presentie', 'van'), 52),
#  (('geboorte', 'desselfs'), 50),
#  (('tot', 'hare'), 50),
#  (('dat', 'de'), 50),
#  (('aldus', 'gedaen'), 50),
#  (('off', 'bij'), 50),
#  (('alle', 'andere'), 49),
#  (('des', 'doots,'), 49),
#  (('ter', 'presentie'), 49),
#  (('ende', 'uijterste'), 48),
#  (('soo', 'die'), 48),
#  (('versocht', 'ende'), 48),
#  (('ende', 'in'), 48),
#  (('vander', 'geboorte'), 47),
#  (('sij', 'testatrice'), 47),
#  (('ende', 'van'), 47),
#  (('winter', 'binnen'), 45),
#  (('te', 'sijn'), 45),
#  (('de', 'klocke'), 45),
#  (('inden', 'jare'), 44),
#  (('gelijck', 'sulcx'), 44),
#  (('voor', 'overlijden'), 44),
#  (('tot', 'dieneijnde'), 44),
#  (('uijterste', 'wille'), 43),
#  (('sal', 'werden'), 43),
#  (('testament', 'ende'), 43),
#  (('van', 'haer'), 42),
#  (('de', 'voorn.'), 42),
#  (('schoon', 'dat'), 42),
#  (('jare', 'vander'), 41),
#  (('bij', 'de'), 41),
#  (('deser', 'stede'), 40),
#  (('in', 'desen'), 40),
#  (('hare', 'voorsz.'), 40),
#  (('ofte', 'als'), 40),
#  (('residerende', 'openbaer'), 39),
#  (('langstlevenden', 'van'), 39),
#  (('sulcx', 'uijterlijck'), 38),
#  (('metter', 'doot'), 38),
#  (('bij', 'haer'), 38),
#  (('hondert', 'ende'), 38),
#  (('na', 'rechten'), 38),
#  (('desselfs', 'onses'), 37),
#  (('soorten', 'van'), 37),
#  (('te', 'hebben'), 37),
#  (('inde', 'quohieren'), 36),
#  (('uijterste', 'wille,'), 36),
#  (('uijt', 'te'), 36),
#  (('van', 'sijn'), 36),
#  (('van', 'hare'), 35),
#  (('als', 'met'), 35),
#  (('ende', 'op'), 34),
#  (('twelck', 'voorsz.'), 34),
#  (('ende', 'tnegentigh,'), 34),
#  (('onses', 'heeren'), 33),
#  (('op', 'een'), 33),
#  (('alle', 'twelck'), 33),
#  (('off', 'kostuijmen'), 33),
#  (('mochten', 'sijn'), 33),
#  (('notarij', 'gestaen'), 33),
#  (('ende', 'dirck'), 33),
#  (('gelooffwaerdige', 'getuijgen'), 33),
#  (('sestien', 'hondert'), 33),
#  (('j:', 'de'), 33),
#  (('quohieren', 'vande'), 32),
#  (('tnegentigh,', 'op'), 32),
#  (('ende', 'te'), 32),
#  (('deser', 'stede,'), 32),
#  (('alle', 'sodanige'), 32),
#  (('eenige', 'ende'), 32),
#  (('op', 'den'), 32),
#  (('best', 'bestaen'), 32),
#  (('onderhouden', 'ende'), 32),
#  (('in', 'alle'), 32),
#  (('alle', 'deselve'), 32),
#  (('desen', 'gemaeckt'), 31),
#  (('alle', 'voorgaende'), 31),
#  (('en', 'alle'), 31),
#  (('op', 'de'), 31),
#  (('segel', 'van'), 30),
#  (('amen', 'inden'), 30),
#  (('openbaer', 'notaris'), 30),
#  (('des', 'doots'), 30),
#  (('van', 'den'), 30),
#  (('die', 'best'), 30),
#  (('alwaert', 'schoon'), 30),
#  (('en', 'mochten'), 30),
#  (('doot', 'deser'), 30),
#  (('gestelt', 'ende'), 30),
#  (('amstelredamme', 'residerende'), 29),
#  (('wel', 'hebbende'), 29),
#  (('allen', 'den'), 29),
#  (('komen', 'te'), 29),
#  (('mogen', 'werden,'), 29),
#  (('off', 'voor'), 29),
#  (('voor', 'date'), 29),
#  (('gehouden', 'te'), 29),
#  (('voorsz.', 'staet'), 29),
#  (('off', 'andersints'), 29),
#  (('bij', 'desen'), 29),
#  (('verklaert', 'inde'), 28),
#  (('memorie', 'ende'), 28),
#  (('uijtspraecke', 'gelijck'), 28),
#  (('van', 'ziel'), 28),
#  (('daer', 'mede'), 28),
#  (('mits', 'desen,'), 28),
#  (('rechten', 'off'), 28),
#  (('werden', 'onderhouden'), 28),
#  (('voor', 'eenige'), 28),
#  (('/', 'en'), 28),
#  (('seeckerheijt', 'des'), 27),
#  (('andere', 'soorten'), 27),
#  (('van', 'uijterste'), 27),
#  (('van', 'noden'), 27),
#  (('in', 'allen'), 27),
#  (('van', 'dese'), 27),
#  (('hebbende', 'en'), 27),
#  (('doende', 'tot'), 27),
#  (('met', 'haer'), 27),
#  (('de', 'langstlevenden'), 27),
#  (('daer', 'van'), 27),
#  (('ende', 'uijtspraecke'), 26),
#  (('overdenckende', 'de'), 26),
#  (('heeft', 'sij'), 26),
#  (('daer', 'toe'), 26),
#  (('dat', 'deselve'), 26),
#  (('ende', 'geroepen'), 26),
#  (('van', 'de'), 26),
#  (('off', 'bevonden'), 26),
#  (('heeren', 'amen'), 26),
#  (('dit', 'segel'), 26),
#  (('vande', 'voorsz.'), 26),
#  (('kinderen', 'en'), 25),
#  (('bij', 'voor'), 25),
#  (('overlijden', 'van'), 25),
#  (('sonder', 'eenige'), 25),
#  (('onverbreeckelijck', 'sal'), 25),
#  (('gestaen', 'opte'), 25),
#  (('doots,', 'ende'), 25),
#  (('naer', 'christelijcke'), 25),
#  (('ten', 'huijse'), 25),
#  (('niet', 'en'), 25),
#  (('van', 'een'), 25),
#  (('van', 'drie'), 24),
#  (('in', 'sijn'), 24),
#  (('de', 'welcke'), 24),
#  (('gestelt,', 'ende'), 24),
#  (('desen', 'van'), 24),
#  (('van', 'deser'), 24),
#  (('hare', 'testatrices'), 24),
#  (('ende', 'gerechticheden'), 24),
#  (('ende', 'onverbreeckelijck'), 24),
#  (('gesont', 'van'), 24),
#  (('heeren', 'sestien'), 24),
#  (('gepasseert', 'off'), 24),
#  (('in', 'leven'), 24),
#  (('andersints', 'soo'), 24),
#  (('compareerde', 'voor'), 23),
#  (('stede', 'mij'), 23),
#  (('sonder', 'dat'), 23),
#  (('ende', 'besproocken'), 23),
#  (('ter', 'saecke'), 23),
#  (('doots,', 'off'), 23),
#  (('bevonden', 'soude'), 23),
#  (('nogh', 'te'), 23),
#  (('willende', 'alle'), 23),
#  (('als', 'alsulcx'), 23),
#  (('noden', 'soude'), 22),
#  (('ontruijmen', 'ende'), 22),
#  (('hare', 'eenige'), 22),
#  (('saecke', 'des'), 22),
#  (('de', 'winter,'), 22),
#  (('ende', 'sonder'), 22),
#  (('behoort', 'tot'), 21),
#  (('een', 'nieuws'), 21),
#  (('/', 'als'), 21),
#  (('vande', 'voorn.'), 21),
#  (('wilde', 'als'), 21),
#  (('der', 'selver'), 21),
#  (('gehouden', 'sijn,'), 21),
#  (('off', 'kinderen'), 21),
#  (('ter', 'contrarie'), 21),
#  (('haer', 'na'), 21),
#  (('hier', 'toe'), 21),
#  (('doot', 'ende'), 20),
#  (('gehouden', 'sijn'), 20),
#  (('te', 'wesen'), 20),
#  (('haer', 'testament'), 20),
#  (('bij', 'plaets'), 20),
#  (('doots', 'off'), 20),
#  (('woonachtigh', 'inde'), 20),
#  (('de', 'broosheijt'), 20),
#  (('date', 'deses'), 20),
#  (('hebben', 'voor'), 20),
#  (('alle', 'hare'), 20),
#  (('deser', 'werelt'), 20),
#  (('dieneijnde', 'alle'), 20),
#  (('onder', 'de'), 20),
#  (('ende', 'tot'), 20),
#  (('nogh', 'in'), 20),
#  (('gelegen,', 'off'), 20),
#  (('sal', 'mogen'), 20),
#  (('guldens', 'eens,'), 20),
#  (('ende', 'erffelijck'), 20),
#  (('voorsz.', 'toekomende'), 20),
#  (('van', 'wijlen'), 19),
#  (('des', 'levens,'), 19),
#  (('kinderen', 'van'), 19),
#  (('gemaeckt', 'ende'), 19),
#  (('als', 'codicille,'), 19),
#  (('off', 'andersints,'), 19),
#  (('bestaen', 'magh'), 19),
#  (('dochter', 'van'), 19),
#  (('en', 'uijterste'), 19),
#  (('op', 'te'), 19),
#  (('en', 'volkomentlijck'), 19),
#  (('broosheijt', 'des'), 19),
#  (('off', 'clausulen'), 19),
#  (('deselve', 'gehouden'), 19),
#  (('sij', 'testateuren'), 19),
#  (('off', 'te'), 19),
#  (('hij', 'testateur'), 19),
#  (('hondert', 'caroli'), 19),
#  (('ende', 'sulcx'), 19),
#  (('n.p.', 'ƒ'), 18),
#  (('weduwe', 'van'), 18),
#  (('ure', 'vandien'), 18),
#  (('ziel', 'ende'), 18),
#  (('off', 'haer'), 18),
#  (('stede,', 'mij'), 18),
#  (('van', 'holland'), 18),
#  (('mede', 'te'), 18),
#  (('compareerden', 'voor'), 18),
#  (('hebben', 'sij'), 18),
#  (('van', 'han'), 18),
#  (('alsulcx', 'ofte'), 18),
#  (('als', 'vooren,'), 18),
#  (('wille', 'ende'), 18),
#  (('soo', 'sal'), 18),
#  (('hen', 'beijden,'), 18),
#  (('die', 'hij'), 18),
#  (('vandien', 'heeft'), 17),
#  (('uijterste', 'willens'), 17),
#  (('mogen', 'sijn'), 17),
#  (('wetten', 'ter'), 17),
#  (('voorsz.', 'kinderen'), 17),
#  (('off', 'hare'), 17),
#  (('met', 'sijn'), 17),
#  (('andersints,', 'soo'), 17),
#  (('soo', 'sij'), 17),
#  (('giste', 'ter'), 17),
#  (('bestaen', 'magh,'), 17),
#  (('sullen', 'mogen'), 17),
#  (('clausulen', 'na'), 17),
#  (('gestaen,', 'gelegen,'), 17),
#  (('mogen', 'doen'), 17),
#  (('ende', 'nagekomen,'), 17),
#  (('klercken', 'gelooffwaerdige'), 17),
#  (('ende', 'geroepe'), 17),
#  (('notario', 'bekent,'), 17),
#  (('memorie,', 'ende'), 17),
#  (('en', 'andere'), 17),
#  (('drie', 'gul.'), 16),
#  (('gul.', 'behoort'), 16),
#  (('uijterlijck', 'bleeck'), 16),
#  (('bleeck', 'wel'), 16),
#  (('levens,', 'seeckerheijt'), 16),
#  (('recommandatie', 'van'), 16),
#  (('haer', 'voorn.'), 16),
#  (('met', 'gelijcke'), 16),
#  (('vast,', 'ende'), 16),
#  (('met', 'en'), 16),
#  (('heeft', 'naer'), 16),
#  (('waer', 'die'), 16),
#  (('die', 'gestaen,'), 16),
#  (('werden,', 'die'), 16),
#  (('testament', 'en'), 16),
#  (('als', 'codicille'), 16),
#  (('jan', 'oorthoorn'), 16),
#  (('kostuijmen', 'vereijscht,'), 16),
#  (('amstelredamme', 'ten'), 16),
#  (('mijns', 'notarij'), 16),
#  (('hebbende', 'ende'), 16),
#  (('bij', 'sonder'), 16),
#  (('hen', 'beijden'), 16),
#  (('nagekomen,', 'alwaert'), 16),
#  (('verklaren', 'inde'), 16),
#  (('klocke', 'bij'), 16),
#  (('alle', 'welcke'), 16),
#  (('hare', 'vrije'), 16),
#  (('vrije', 'wille'), 16),
#  (('sal', 'sijn'), 16),
#  (('ende', 'sullen'), 16),
#  (('ende', 'jan'), 16),
#  (('ende', 'genommeert'), 16),
#  (('als', 'vooren'), 16),
#  (('als', 'off'), 16),
#  (('tot', 'een'), 16),
#  (('jacobus', 'de'), 16),
#  (('testamente', 'van'), 15),
#  (('off', 'andere'), 15),
#  (('sal', 'hebben'), 15),
#  (('off', 'meer'), 15),
#  (('sullen', 'moeten'), 15),
#  (('verklaerde', 'sij'), 15),
#  (('sal', 'komen'), 15),
#  (('wilde', 'sij'), 15),
#  (('geordonneert)', 'die'), 15),
#  (('gemaeckt', 'haer'), 15),
#  (('vast', 'ende'), 15),
#  (('off', 'nogh'), 15),
#  (('daer', 'uijt'), 15),
#  (('te', 'niet'), 15),
#  (('haer', 'testatrice'), 15),
#  (('ende', 'voort'), 15),
#  (('werelt', 'ontruijmen'), 15),
#  (('als', 'deselve'), 15),
#  (('gestaen', 'als'), 15),
#  (('sijn', 'off'), 15),
#  (('sal', 'de'), 15),
#  (('van', 'der'), 15),
#  (('jan', 'bollaert'), 15),
#  (('te', 'maecken,'), 15),
#  (('mogen', 'werden'), 15),
#  (('onder', 'den'), 15),
#  (('hier', 'na'), 15),
#  (('bij', 'aldien'), 15),
#  (('sijn', 'leven'), 14),
#  (('in', 'de'), 14),
#  (('haer', 'testatrices'), 14),
#  (('een', 'off'), 14),
#  (('van', 'desen'), 14),
#  (('voorsz.', 'staet,'), 14),
#  (('item', 'aen'), 14),
#  (('wede.', 'van'), 14),
#  (('niet', 'te'), 14),
#  (('ende', 'hare'), 14),
#  (('huijse', 'mijns'), 14),
#  (('opte', 'oudesijts'), 14),
#  (('krachteloos,', 'ende'), 14),
#  (('erffelijck', 'daer'), 14),
#  (('tot', 'deese'), 14),
#  (('over', 'hare'), 14),
#  (('dieneijnde', 'allen'), 14),
#  (('huijse', 'van'), 14),
#  (('dat', 'hij'), 14),
#  (('en', 'sal'), 14),
#  (('en', 'van'), 14),
#  (('voort', 'met'), 14),
#  (('int', 'geheel'), 14),
#  (('ende', 'daer'), 14),
#  (('na', 'rechte'), 14),
#  (('gestelt', 'bij'), 14),
#  (('sijn', 'getanxeert'), 13),
#  (('heeren', 'sestienhondert'), 13),
#  (('notario', 'bekent'), 13),
#  (('volkomentlijck', 'gebruijckende'), 13),
#  (('den', 'anderen'), 13),
#  (('dat', 'sij'), 13),
#  (('rechten', 'ende'), 13),
#  (('gerechticheden', 'egeene'), 13),
#  (('mitsgaders', 'tot'), 13),
#  (('dewelcke', 'overdenckende'), 13),
#  (('gestaen', 'op'), 13),
#  (('oorthoorn', 'mede'), 13),
#  (('sodanige', 'generale'), 13),
#  (('doot,', 'ende'), 13),
#  (('voor', 'de'), 13),
#  (('bij', 'den'), 13),
#  (('deses', 'eenichsints'), 13),
#  (('ende', 'naerlaten'), 13),
#  (('ende', 'een'), 13),
#  (('en', 'de'), 13),
#  (('naerlaten', 'sal'), 13),
#  (('kinderen', 'met'), 13),
#  (('mogen', 'komen'), 13),
#  (('hier', 'toespecialijcken'), 13),
#  (('sestienhondert', 'ende'), 13),
#  (('off', 'verleden,'), 13),
#  (('winter', 'n.p'), 13),
#  (('bij', 'sijn'), 13),
#  (('nieuws', 'disponerende,'), 12),
#  (('off', 'anders'), 12),
#  (('ende', 'gecommitteert'), 12),
#  (('van', 'deselve'), 12),
#  (('egeene', 'uijtgesondert'), 12),
#  (('ofte', 'bij'), 12),
#  (('alsoo', 'geordonneert)'), 12),
#  (('sij', 'wilde'), 12),
#  (('geobserveert', 'aldus'), 12),
#  (('klocke', 'halff'), 12),
#  (('oudesijts', 'voorburghwal'), 12),
#  (('goederen', 'en'), 12),
#  (('sullen', 'komen'), 12),
#  (('woonachtigh', 'tot'), 12),
#  (('niet', 'doende'), 12),
#  (('sonder', 'voor'), 12),
#  (('de', 'selve'), 12),
#  (('en', 'goederen'), 12),
#  (('verklaerden', 'sij'), 12),
#  (('sij', 'wilden'), 12),
#  (('soo', 'de'), 12),
#  (('met', 'te'), 12),
#  (('als', 'de'), 12),
#  (('en', 'anders'), 12),
#  (('/', 'ende'), 12),
#  (('en', 'seeckere'), 12),
#  (('seeckere', 'getuijgen'), 12),
#  (('lasten,', 'off'), 12),
#  (('quame', 'te'), 12),
#  (('behoudens', 'haer'), 12),
#  (('amstelredamme,', 'ten'), 12),
#  (('voorgaende', 'testamenten,'), 12),
#  (('van', 'allen'), 12),
#  (('tot', 'vooghden'), 12),
#  (('hen', 'testateuren'), 12),
#  (('sijn', 'testateurs'), 12),
#  (('winter', 'ende'), 12),
#  (('sijn', 'testament'), 12),
#  (('dogh', 'andersints'), 11),
#  (('te', 'doen'), 11),
#  (('sal', 'sijn,'), 11),
#  (('ende', 'soo'), 11),
#  (('gecommitteert', 'mits'), 11),
#  (('en', 'in'), 11),
#  (('tallen', 'tijden'), 11),
#  (('waer', 'op'), 11),
#  (('allen', 'rechten'), 11),
#  (('na', 'haer'), 11),
#  (('wesen', 'haer'), 11),
#  (('descendenten', 'bij'), 11),
#  (('aen', 'hare'), 11),
#  (('sijn', 'geobserveert'), 11),
#  (('winter,', 'ende'), 11),
#  (('j:dewinter', 'n.p.'), 11),
#  (('des', 'levens'), 11),
#  (('crediten,', 'ende'), 11),
#  (('gelegen', 'off'), 11),
#  (('haer', 'voor'), 11),
#  (('ende', 'nagekomen'), 11),
#  (('hove', 'van'), 11),
#  (('eenige', 'hoedanige'), 11),
#  (('mogen', 'sijn,'), 11),
#  (('als', 'alsulcx,'), 11),
#  (('net', 'en'), 11),
#  (('eenichsints', 'gepasseert'), 11),
#  (('openbaer', 'nots.'), 11),
#  (('den', 'goederen,'), 11),
#  (('ende', 'tnegentigh'), 11),
#  (('off', 'anderen'), 11),
#  (('dit', 'alles'), 11),
#  (('nogh', 'de'), 11),
#  (('alsdan', 'nogh'), 11),
#  (('magh', 'vast'), 11),
#  (('penningh', 'met'), 11),
#  (('ende', 'de'), 11),
#  (('en', 'naerlaten'), 11),
#  (('op', 'hare'), 11),
#  (('voor', 'soo'), 11),
#  (('verstant,', 'memorie,'), 11),
#  (('eenige', 'actien'), 11),
#  (('actien', 'daer'), 11),
#  (('gelijcke', 'machte'), 11),
#  (('binnen', 'amstelredamme,'), 11),
#  (('bleeck,', 'wel'), 11),
#  (('bij', 'henlieden'), 11),
#  (('ende', 'na'), 11),
#  (('ende', 'dit'), 11),
#  (('sal', 'gehouden'), 11),
#  (('wilden', 'als'), 11),
#  (('te', 'sullen'), 11),
#  (('gul.', 'te'), 11),
#  (('geliefte,', 'als'), 11),
#  (('toe', 'specialijcken'), 11),
#  (('notaris', 'en'), 11),
#  (('sijn', 'ende'), 11),
#  (('vijftigh', 'caroli'), 11),
#  (('ter', 'andere'), 11),
#  (('deselve', 'hare'), 11),
#  (('heeft', 'hij'), 11),
#  (('sijn', 'voor'), 11),
#  (('bij', 'desen,'), 11),
#  (('desomme', 'van'), 11),
#  (('verleden,', 'willende'), 11),
#  (('huijs', 'en'), 10),
#  (('offererende', 'alle'), 10),
#  (('als', 'henlieden'), 10),
#  (('ende', 'haer'), 10),
#  (('verstant,', 'memorie'), 10),
#  (('actien,', 'crediten,'), 10),
#  (('ende', 'gerechticheden,'), 10),
#  (('tsij', 'waer'), 10),
#  (('eenichsints', 'metter'), 10),
#  (('nagekomen', 'alwaert'), 10),
#  (('voorburghwal', 'bijde'), 10),
#  (('sij', 'testatrice,'), 10),
#  (('dese', 'hare'), 10),
#  (('soude', 'willen'), 10),
#  (('deroguerende', 'tot'), 10),
#  (('dispositien,', 'bij'), 10),
#  (('vereijscht,', 'hierinne'), 10),
#  (('mede', 'nots.'), 10),
#  (('ende', 'genommeert,'), 10),
#  (('genommeert,', 'soo'), 10),
#  (('haer', 'vrije'), 10),
#  (('klocke', 'over'), 10),
#  (('ende', 'volkomentlijck'), 10),
#  (('hebben', 'naer'), 10),
#  (('dispositien', 'bij'), 10),
#  (('off', 'kinderen,'), 10),
#  (('en', 'lager'), 10),
#  (('eijgen', 'beweginge'), 10),
#  (('toespecialijcken', 'versocht'), 10),
#  (('gebruijckende', 'dewelcke'), 10),
#  (('alle', 'ander'), 10),
#  (('maer', 'andersints'), 10),
#  (('dat', 'voor'), 10),
#  (('/', 'off'), 10),
#  (('sal', 'worden'), 10),
#  (('winter,', 'binnen'), 10),
#  (('uijterlijck', 'bleeck,'), 10),
#  (('sal', 'moeten'), 10),
#  (('sullen', 'de'), 10),
#  (('van', 'eenhondert'), 10),
#  (('voorts', 'heeft'), 10),
#  (('notario', 'en'), 10),
#  (('sal', 'deselve'), 10),
#  (('off', 'kommeren'), 10),
#  (('nogh', 'sal'), 10),
#  (('t', 'sij'), 10),
#  (('te', 'maecken'), 10),
#  (('soo', 'als'), 10),
#  (('en', 'wetten'), 10),
#  (('christelijcke', 'recommandatie'), 10),
#  (('en', 'komende'), 10),
#  (('staet', 'off'), 10),
#  (('vooghden', 'na'), 10),
#  (('oude', 'sijts'), 10),
#  (('als', 'hij'), 10),
#  (('mogen', 'doen,'), 10),
#  (('alle', 'de'), 10),
#  (('dese', 'testamente'), 10),
#  (('goederen,', 'roerende,'), 10),
#  (('off', 'het'), 10),
#  (('goederen', 'is'), 10),
#  (('off', 'die'), 10),
#  (('gemaeckt', 'haerlieder'), 10),
#  (('hij', 'wilde'), 10),
#  (('jan', 'bollaert,'), 10),
#  (('van', 'jacobus'), 10),
#  (('goede', 'bekende'), 9),
#  (('toe', 'mits'), 9),
#  (('desen', 'gevende'), 9),
#  (('ende', 'waer'), 9),
#  (('en', 'sullen'), 9),
#  (('als', 'sij'), 9),
#  (('deselve', 'kinderen'), 9),
#  (('testatrice', 'tot'), 9),
#  (('penningh', 'niet'), 9),
#  (('tnegentigh', 'op'), 9),
#  (('uijterlijck', 'bleeckwel'), 9),
#  (('bleeckwel', 'hebbende'), 9),
#  (('levens', 'seeckerheijt'), 9),
#  (('hare', 'goederen,'), 9),
#  (('gemaeckt', 'off'), 9),
#  (('generale', 'ende'), 9),
#  (('rechten,', 'ende'), 9),
#  (('willen', 'off'), 9),
#  (('alsulcx,', 'ofte'), 9),
#  (('van', 'iemand'), 9),
#  (('van', 'henlieden'), 9),
#  (('staet', 'verklaerde'), 9),
#  (('van', 'ouwaerden'), 9),
#  (('kind', 'off'), 9),
#  (('crediten', 'ende'), 9),
#  (('van', 'alle'), 9),
#  (('des', 'heeren'), 9),
#  (('codicillen,', 'en'), 9),
#  (('in', 'wesen'), 9),
#  (('buijten', 'de'), 9),
#  (('minste', 'nogh'), 9),
#  (('ziel', 'en'), 9),
#  (('haerlieder', 'testament'), 9),
#  (('als', 'mede'), 9),
#  (('huijsemijns', 'notarij'), 9),
#  (('uijterste', 'willems'), 9),
#  (('huijsvrouw', 'van'), 9),
#  (('ende', 'voor'), 9),
#  (('voor', 'alle'), 9),
#  (('soo', 'van'), 9),
#  (('als', 'andere'), 9),
#  (('ende', 'alsoo'), 9),
#  (('tot', 'sijn'), 9),
#  (('gemaeckt,', 'ende'), 9),
#  (('geheel', 'ende'), 9),
#  (('vruchten', 'en'), 9),
#  (('soo', 'sullen'), 9),
#  (('desen', 'de'), 9),
#  (('saturdagh', 'den'), 9),
#  (('nogh', 'geven'), 9),
#  (('vaders', 'off'), 9),
#  (('sal', 'gelieven'), 9),
#  (('met', 'speciale'), 9),
#  (('legitime', 'portie,'), 9),
#  (('sullen', 'sijn'), 9),
#  (('na', 'dat'), 9),
#  (('ende', 'hier'), 9),
#  (('van', 'onwaerden'), 9),
#  (('en', 'voorwaerden'), 9),
#  (('vande', 'langstlevenden'), 9),
#  (('haer', 'voorsz.'), 9),
#  (('nieuws', 'disponerende'), 9),
#  (('dat', 'het'), 9),
#  (('getuijgen', 'gepasseert'), 9),
#  (('beweginge', 'alsoo'), 9),
#  (('dat', 'onder'), 9),
#  (('bij', 'hem'), 9),
#  (('eeuwelijck', 'ende'), 9),
#  (('caroli', 'gul.'), 9),
#  (('duijsent', 'caroli'), 9),
#  (('soo', 'hij'), 9),
#  (('voor', 'notaris'), 9),
#  (('off', 'verleden'), 9),
#  (('van', 'vijftigh'), 9),
#  (('ontruijmen', 'en'), 9),
#  (('een', 'ditto'), 9),
#  (('een', 'silvere'), 9),
#  (('catharina', 'van'), 9),
#  (('sijn', 'voorn.'), 9),
#  (('jan', 'jacobsz'), 9),
#  (('ao.', 'xvic.'), 8),
#  (('welcke', 'overdenckende'), 8),
#  (('te', 'met'), 8),
#  (('disponerende,', 'heeft'), 8),
#  (('gerrit', 'jansz'), 8),
#  (('tegens', 'den'), 8),
#  (('aen', 'haer'), 8),
#  (('off', 'in'), 8),
#  (('op', 'sij'), 8),
#  (('en', 'te'), 8),
#  (('doot', 'sal'), 8),
#  (('de', 'goederen'), 8),
#  (('magh', 'vast,'), 8),
#  (('van', 'pieter'), 8),
#  (('gebruijckende,', 'dewelcke'), 8),
#  (('naerlaten', 'sal,'), 8),
#  (('geinstitueert,', 'gestelt,'), 8),
#  (('getrouwt', 'met'), 8),
#  (('codicille', 'giste'), 8),
#  (('soo', 'wilde'), 8),
#  (('de', 'vruchten'), 8),
#  (('mede', 'de'), 8),
#  (('nots.', 'bij'), 8),
#  (('dirck', 'oorgeest'), 8),
#  (('iemand', 'van'), 8),
#  (('kinderen', 'bij'), 8),
#  (('vrije', 'eijgen'), 8),
#  (('ter', 'werelt'), 8),
#  (('vandien', 'hebben'), 8),
#  (('sijne', 'off'), 8),
#  (('daer', 'op'), 8),
#  (('en', 'vorder'), 8),
#  (('te', 'doteren'), 8),
#  (('met', 'sodanige'), 8),
#  (('voorts', 'sij'), 8),
#  (('sijn,', 'ende'), 8),
#  (('magh,', 'vast,'), 8),
#  (('alsdan', 'in'), 8),
#  (('harl', 'voorsz.'), 8),
#  (('int', 'minste'), 8),
#  (('in', 'handen'), 8),
#  (('sijn', 'voorsz.'), 8),
#  (('dat', 'in'), 8),
#  (('off', 'ander'), 8),
#  (('tot', 'soo'), 8),
#  (('ende', 'bij'), 8),
#  (('vijff', 'hondert'), 8),
#  (('duijsent', 'gul.'), 8),
#  (('maecken,', 'off'), 8),
#  (('hebben', 'mits'), 8),
#  (('hierinne', 'niet'), 8),
#  (('op', 'saturdagh'), 8),
#  (('savonts', 'de'), 8),
#  (('echteluijden', 'woonachtigh'), 8),
#  (('ende', "d'onseeckere"), 8),
#  (('voor', 'alsulcke'), 8),
#  (('tot', 'eenige'), 8),
#  (('met', 'konsent'), 8),
#  (('konsent', 'als'), 8),
#  (('portie', 'off'), 8),
#  (('recht', 'van'), 8),
#  (('over', 'de'), 8),
#  (('daer', 'tol'), 8),
#  (('sijn', 'getauxeert'), 8),
#  (('bekent,', 'gesont'), 8),
#  (('int', 'bij'), 8),
#  (('van', 'gelder,'), 8),
#  (('deselve', 'alsdan'), 8),
#  (('ende', 'sijn'), 8),
#  (('heeren', 'weesmrn.'), 8),
#  (('een', 'ieder'), 8),
#  (('een', 'ander'), 8),
#  (('conditien', 'en'), 8),
#  (('specialijcken', 'versocht'), 8),
#  (('verklaerde', 'hij'), 8),
#  (('en', 'bundigh'), 8),
#  (('hen', 'testateuren,'), 8),
#  (('van', 'eenige'), 8),
#  (('aen', 'sijn'), 8),
#  (('man', 'jan'), 8),
#  (('te', 'keeren'), 8),
#  (('ten', 'behoeve'), 8),
#  (('vierduijsent', 'gul.'), 7),
#  (('heeren:', 'amen'), 7),
#  (('uren', 'compareerde'), 7),
#  (('verstant', 'memorie'), 7),
#  (('gebruijckende', 'de'), 7),
#  (("d'onsekere", 'ure'), 7),
#  (('met', 'doende'), 7),
#  (('ende', 'aen'), 7),
#  (('soo', 'volcht'), 7),
#  (('volcht', 'als'), 7),
#  (('ende', 'speciale'), 7),
#  (('off', 'gesagh'), 7),
#  (('gesagh', 'in'), 7),
#  (('haren', 'boedel'), 7),
#  (('ende', 'wetten'), 7),
#  (('dat', 'hare'), 7),
#  (('sullen', 'hebben'), 7),
#  (('oock', 'soude'), 7),
#  (('staet,', 'verklaerde'), 7),
#  (('een', 'dochter'), 7),
#  (('guldens', 'eens'), 7),
#  (('aende', 'voorn.'), 7),
#  (('wijders', 'metter'), 7),
#  (('voor', 'een'), 7),
#  (('uijtkrachte', 'deses'), 7),
#  (('tot', 'op'), 7),
#  (('tot', 'executeurs'), 7),
#  (('executeurs', 'van'), 7),
#  (('tot', 'regenten'), 7),
#  (('kostuijmen', 'vereijscht'), 7),
#  (('voorburghwal', 'bij'), 7),
#  (('hare', 'verstant,'), 7),
#  (('met', 'een'), 7),
#  (('en', 'middelen'), 7),
#  (('mogen', 'aengesproocken,'), 7),
#  (('aengesproocken,', 'off'), 7),
#  (('van', 'off'), 7),
#  (('hare', 'uijterste'), 7),
#  (('ende', 'alle'), 7),
#  (('op', 'donderdagh'), 7),
#  (('donderdagh', 'den'), 7),
#  (('doots,', 'en'), 7),
#  (('haer', 'gemelte'), 7),
#  (('des', 'jaers'), 7),
#  (('willens', 'dispositien,'), 7),
#  (('hierinne', 'net'), 7),
#  (('den', 'hove'), 7),
#  (('testatrice', 'voor'), 7),
#  (('gerechticheden,', 'egeene'), 7),
#  (('voor', 'ende'), 7),
#  (('iets', 'uijt'), 7),
#  (('deese', 'annexe'), 7),
#  (('ende', "d'onsekere"), 7),
#  (('willens', 'dispositien'), 7),
#  (('tesamen,', 'off'), 7),
#  (('disponerende,', 'hebben'), 7),
#  (('nommeerden', 'mits'), 7),
#  (('te', 'onderhouden,'), 7),
#  (('tot', 'regent'), 7),
#  (('contrarie', 'dicterende'), 7),
#  (('haerlieder', 'respective'), 7),
#  (('namebes', 'heeren'), 7),
#  (('binnen', 'daser'), 7),
#  (('deselve', 'langstlevenden'), 7),
#  (('als', 'voren'), 7),
#  (('anders', 'off'), 7),
#  (('der', 'geboorte'), 7),
#  (('casserende,', 'doot'), 7),
#  (('off', 'sonder'), 7),
#  (('soo', 'veel'), 7),
#  (('levenden', 'van'), 7),
#  (('off', 'wel'), 7),
#  (('bollaert', 'ende'), 7),
#  (('dirck', 'dorgeest'), 7),
#  (('nameles', 'heeren'), 7),
#  (('doots', 'ende'), 7),
#  (('testament', 'van'), 7),
#  (('des', 'sal'), 7),
#  (('vande', 'selve'), 7),
#  (('off', 'uijt'), 7),
#  (('besproocken', 'mits'), 7),
#  (('ende', 'sal'), 7),
#  (('een', 'somme'), 7),
#  (('sullen', 'hebben,'), 7),
#  (('contrarie', 'dicterende,'), 7),
#  (('wel', 'expresselijck'), 7),
#  (('met', 'hare'), 7),
#  (("d'langstlevenden", 'van'), 7),
#  (('eenige', 'andere'), 7),
#  (('soo', 'ende'), 7),
#  (('actien,', 'ende'), 7),
#  (('deselve', 'goederen'), 7),
#  (('sijn,', 'voort'), 7),
#  (('de', 'weeskamer'), 7),
#  (('soo', 'voorgaende'), 7),
#  (('voorgaende', 'als'), 7),
#  (('respective', 'testament'), 7),
#  (('sulcx', 'binnen'), 7),
#  (('sullen', 'sijn,'), 7),
#  (('ende', 'lichaem'), 7),
#  (('die', 'bij'), 7),
#  (('na', 'sijn'), 7),
#  (('woonachtigh', 'binnen'), 7),
#  (('codicillen', 'en'), 7),
#  (('disponerende', 'heeft'), 7),
#  (('het', 'selvige'), 7),
#  (('desen', 'geschreven'), 7),
#  (('toekomende', 'bruijdegom'), 7),
#  (('toekomende', 'bruijdegom,'), 7),
#  (('actien,', 'crediten'), 7),
#  (('anders', 'niet'), 7),
#  (('toekomende', 'echteluijden'), 7),
#  (('en', 'offererende'), 7),
#  (('machte,', 'als'), 7),
#  (('wille', 'en'), 7),
#  (('van', 'hem'), 7),
#  (('gemaeckt', 'sijn'), 7),
#  (('plaets', 'vullinge,'), 7),
#  (('desen', 'wel'), 7),
#  (('portie', 'haer'), 7),
#  (('den', 'off'), 7),
#  (('tot', 'haer'), 7),
#  (('als', 'nogh'), 7),
#  (('dat', 'sijn'), 7),
#  (('bundigh', 'sal'), 7),
#  (('sij', 'testateuren,'), 7),
#  (('gelieven', 'te'), 7),
#  (('en', 'wijle'), 7),
#  (('machte', 'als'), 7),
#  (('van', 'en'), 7),
#  (('en', 'tot'), 7),
#  (('vooghden', 'over'), 7),
#  (('gul.', 'ƒ'), 7),
#  (('een', 'goude'), 7),
#  (('voor', 'hare'), 7),
#  (('jan', 'van'), 7),
#  (('ƒ', 'ƒ'), 6),
#  (('den', 'elffden'), 6),
#  (('andersints', 'hare'), 6),
#  (('de', 'broofheijt'), 6),
#  (('broofheijt', 'des'), 6),
#  (('annetje', 'jans'), 6),
#  (('ten', 'huwelijck'), 6),
#  (('en', 'groot'), 6),
#  (('deselve', 'daer'), 6),
#  (('tijden', 'een'), 6),
#  (('in', 'haer'), 6),
#  (('de', 'heeren'), 6),
#  (('met', 'willende'), 6),
#  (('willende', 'dat'), 6),
#  (('in', 'haren'), 6),
#  (('te', 'nemene'), 6),
#  (('wilde,', 'dat'), 6),
#  (('den', 'vordere'), 6),
#  (('kinderen', 'ende'), 6),
#  (('en', 'wilde'), 6),
#  (('in', 'reguarde'), 6),
#  (('in', 'prejudicie'), 6),
#  (('off', 'contrarie'), 6),
#  (('pieter', 'de'), 6),
#  (('gestaen,', 'gelegen'), 6),
#  (('sal,', 'tot'), 6),
#  (('voor', 'overlijden,'), 6),
#  (('magh,', 'vast'), 6),
#  (('armsbrugh.', 'ter'), 6),
#  (('ende', 'pieter'), 6),
#  (('te', 'werden'), 6),
#  (('testatrice,', 'dat'), 6),
#  (('en', 'bladeren'), 6),
#  (('leven', 'gedurende,'), 6),
#  (('die', 'eenige'), 6),
#  (('j:', 'dewinter'), 6),
#  (('resommandatie', 'van'), 6),
#  (('huwelijcxe', 'voorwaerden'), 6),
#  (('generalijcken', 'alle'), 6),
#  (('werelt', 'iets'), 6),
#  (('annexe', 'testamente'), 6),
#  (('wel', 'te'), 6),
#  (('dogh', 'beijde'), 6),
#  (('testateuren', 'tot'), 6),
#  (('nogh', 'allen'), 6),
#  (('kinderen,', 'die'), 6),
#  (('vermogen', 'te'), 6),
#  (('langstlevenden', 'gehouden'), 6),
#  (('en', 'klederen'), 6),
#  (('heeren', 'te'), 6),
#  (('doteren', 'ende'), 6),
#  (('regent', 'over'), 6),
#  (('voort', 'alle'), 6),
#  (('staet', 'verklaerden'), 6),
#  (('en', 'sulcx'), 6),
#  (('portie,', 'haer'), 6),
#  (('als', 'na'), 6),
#  (('tot', 'en'), 6),
#  (('en', 'ander'), 6),
#  (('sij', 'waer'), 6),
#  (('die', 'bestbestaen'), 6),
#  (('dat', 'totter'), 6),
#  (('voor', 'mil'), 6),
#  (('met', 'off'), 6),
#  (('in', 'cas'), 6),
#  (('cas', 'van'), 6),
#  (('daer', 'in'), 6),
#  (('deser', 'stadt'), 6),
#  (('woonachtigh', 'opte'), 6),
#  (('te', 'bedde'), 6),
#  (('den', 'testamente'), 6),
#  (('willems', 'dispositien,'), 6),
#  (('te', 'hebben,'), 6),
#  (('annexe', 'testament'), 6),
#  (('door', 'de'), 6),
#  (('gemelte', 'dochter'), 6),
#  (('die', 'gestaen'), 6),
#  (('institueerde,', 'stelde,'), 6),
#  (('bij', 'representatie,'), 6),
#  (('hare', 'kinderen'), 6),
#  (('die', 'alsdan'), 6),
#  (('te', 'rade'), 6),
#  (('alle', 'tselvige'), 6),
#  (('ende', 'waerop'), 6),
#  (('allen', 'rechten,'), 6),
#  (('hem', 'off'), 6),
#  (('^', 'off'), 6),
#  (('dirck', 'dorgeest,'), 6),
#  (('steden', 'off'), 6),
#  (('nogh', 'maecken'), 6),
#  (('maecken', 'nogh'), 6),
#  (('geven', 'eenigen'), 6),
#  (('eenigen', 'inventaris'), 6),
#  (('inventaris', 'der'), 6),
#  (('komende', 'deselve'), 6),
#  (('jaren', 'off'), 6),
#  (('off', 'eenige'), 6),
#  (('malkanderen,', 'ende'), 6),
#  (('en', 'volkomen'), 6),
#  (('den', 'goederen'), 6),
#  (('gelijck', 'sij'), 6),
#  (('niet', 'sal'), 6),
#  (('maecken', 'van'), 6),
#  (('weeskamer', 'als'), 6),
#  (('off', 'moeders'), 6),
#  (('desen', 'stellen'), 6),
#  (('stellen', 'tot'), 6),
#  (('voor', 'en'), 6),
#  (('als', 'navolgende'), 6),
#  (('wesen', 'haerlieder'), 6),
#  (('(uijt', 'eijgen'), 6),
#  (('alles', 'met'), 6),
#  (('overlijden', 'vande'), 6),
#  (('off', 'na'), 6),
#  (('te', 'oude'), 6),
#  (('de', 'langht'), 6),
#  (('gekomen', 'sullen'), 6),
#  (('ten', 'huwelijcken'), 6),
#  (('jaren,', 'off'), 6),
#  (('vorstant', 'memorie'), 6),
#  (('soo', 'bij'), 6),
#  (('van', 'dien'), 6),
#  (('deser', 'stad'), 6),
#  (('de', 'vierduijsent'), 6),
#  (('anna', 'van'), 6),
#  (('met', 'volle'), 6),
#  (('nogh', 'meeste'), 6),
#  (('van', 'institutie'), 6),
#  (('en', 'sonder'), 6),
#  ...]

# %%
tc = Counter([b for b in nltk.trigrams(lwords)])
tc.most_common()
# Out:
# [(('j:de', 'winter', 'n.p.'), 72),
#  (('voor', 'mij', 'jacob'), 67),
#  (('mij', 'jacob', 'de'), 55),
#  (('de', 'somme', 'van'), 52),
#  (('aldus', 'gedaen', 'binnen'), 47),
#  (('ter', 'presentie', 'van'), 46),
#  (('jacob', 'de', 'winter'), 44),
#  (('de', 'winter', 'binnen'), 43),
#  (('vander', 'geboorte', 'desselfs'), 42),
#  (('schoon', 'dat', 'alle'), 40),
#  (('inden', 'jare', 'vander'), 38),
#  (('jare', 'vander', 'geboorte'), 37),
#  (('binnen', 'deser', 'stede'), 37),
#  (('gelijck', 'sulcx', 'uijterlijck'), 35),
#  (('geboorte', 'desselfs', 'onses'), 33),
#  (('testament', 'ende', 'uijterste'), 33),
#  (('j:', 'de', 'winter'), 32),
#  (('desselfs', 'onses', 'heeren'), 31),
#  (('alle', 'twelck', 'voorsz.'), 31),
#  (('inde', 'quohieren', 'vande'), 30),
#  (('binnen', 'deser', 'stede,'), 30),
#  (('en', 'mochten', 'sijn'), 29),
#  (('binnen', 'amstelredamme', 'residerende'), 28),
#  (('residerende', 'openbaer', 'notaris'), 28),
#  (('soo', 'die', 'best'), 28),
#  (('gelooffwaerdige', 'getuijgen', 'hier'), 28),
#  (('ende', 'tnegentigh,', 'op'), 28),
#  (('amstelredamme', 'residerende', 'openbaer'), 27),
#  (('mits', 'desen', 'gemaeckt'), 27),
#  (('andere', 'soorten', 'van'), 27),
#  (('soorten', 'van', 'uijterste'), 27),
#  (('die', 'best', 'bestaen'), 27),
#  (('sal', 'werden', 'onderhouden'), 27),
#  (('alwaert', 'schoon', 'dat'), 27),
#  (('metter', 'doot', 'deser'), 27),
#  (('sestien', 'hondert', 'ende'), 27),
#  (('langstlevenden', 'van', 'hen'), 27),
#  (('winter', 'binnen', 'amstelredamme'), 26),
#  (('ende', 'op', 'een'), 26),
#  (('gedaen', 'binnen', 'amstelredamme'), 26),
#  (('dit', 'segel', 'van'), 26),
#  (('de', 'winter', 'n.p.'), 26),
#  (('ende', 'uijtspraecke', 'gelijck'), 25),
#  (('uijtspraecke', 'gelijck', 'sulcx'), 25),
#  (('alle', 'andere', 'soorten'), 25),
#  (('werden', 'onderhouden', 'ende'), 25),
#  (('in', 'desen', 'van'), 24),
#  (('presentie', 'van', 'jan'), 24),
#  (('amen', 'inden', 'jare'), 23),
#  (('compareerde', 'voor', 'mij'), 23),
#  (('off', 'andersints', 'soo'), 23),
#  (('stede', 'mij', 'notario'), 22),
#  (('ende', 'uijterste', 'wille'), 22),
#  (('bij', 'voor', 'overlijden'), 22),
#  (('off', 'bevonden', 'soude'), 22),
#  (('verklaert', 'inde', 'quohieren'), 21),
#  (('op', 'een', 'nieuws'), 21),
#  (('van', 'noden', 'soude'), 21),
#  (('noden', 'soude', 'mogen'), 21),
#  (('tot', 'hare', 'eenige'), 21),
#  (('voor', 'overlijden', 'van'), 21),
#  (('ter', 'saecke', 'des'), 21),
#  (('ende', 'onverbreeckelijck', 'sal'), 21),
#  (('bevonden', 'soude', 'mogen'), 21),
#  (('off', 'voor', 'eenige'), 21),
#  (('doende', 'tot', 'dieneijnde'), 21),
#  (('gehouden', 'te', 'hebben'), 21),
#  (('na', 'rechten', 'off'), 21),
#  (('hondert', 'ende', 'tnegentigh,'), 21),
#  (('hare', 'eenige', 'ende'), 20),
#  (('onverbreeckelijck', 'sal', 'werden'), 20),
#  (('versocht', 'ende', 'geroepen'), 20),
#  (('heeren', 'amen', 'inden'), 20),
#  (('heeren', 'sestien', 'hondert'), 20),
#  (('te', 'hebben', 'voor'), 20),
#  (('de', 'langstlevenden', 'van'), 20),
#  (('caroli', 'guldens', 'eens,'), 20),
#  (('segel', 'van', 'drie'), 19),
#  (('en', 'alle', 'andere'), 19),
#  (('desen', 'van', 'noden'), 19),
#  (('notarij', 'gestaen', 'opte'), 19),
#  (('des', 'doots,', 'ende'), 19),
#  (('ende', 'in', 'desen'), 19),
#  (('de', 'broosheijt', 'des'), 19),
#  (('voor', 'date', 'deses'), 19),
#  (('tot', 'dieneijnde', 'alle'), 19),
#  (('van', 'ziel', 'ende'), 18),
#  (('des', 'doots,', 'off'), 18),
#  (('deser', 'stede,', 'mij'), 18),
#  (('stede,', 'mij', 'notario'), 18),
#  (('onses', 'heeren', 'sestien'), 18),
#  (('compareerden', 'voor', 'mij'), 18),
#  (('alsulcx', 'ofte', 'als'), 18),
#  (('rechten', 'off', 'kostuijmen'), 18),
#  (('van', 'hen', 'beijden,'), 18),
#  (('wel', 'hebbende', 'en'), 17),
#  (('dieneijnde', 'alle', 'voorgaende'), 17),
#  (('twelck', 'voorsz.', 'staet'), 17),
#  (('andersints', 'soo', 'die'), 17),
#  (('ende', 'uijterste', 'wille,'), 17),
#  (('deser', 'stede', 'mij'), 16),
#  (('doot', 'ende', 'te'), 16),
#  (('van', 'uijterste', 'willens'), 16),
#  (('heeft', 'sij', 'testatrice'), 16),
#  (('seeckerheijt', 'des', 'doots,'), 16),
#  (('des', 'doots', 'off'), 16),
#  (('van', 'jan', 'oorthoorn'), 16),
#  (('off', 'kostuijmen', 'vereijscht,'), 16),
#  (('binnen', 'amstelredamme', 'ten'), 16),
#  (('alle', 'deselve', 'gehouden'), 16),
#  (('deselve', 'gehouden', 'te'), 16),
#  (('gestaen,', 'gelegen,', 'off'), 16),
#  (('gelegen,', 'off', 'bevonden'), 16),
#  (('klercken', 'gelooffwaerdige', 'getuijgen'), 16),
#  (('mij', 'notario', 'bekent,'), 16),
#  (('als', 'alsulcx', 'ofte'), 16),
#  (('van', 'drie', 'gul.'), 15),
#  (('gul.', 'behoort', 'tot'), 15),
#  (('sulcx', 'uijterlijck', 'bleeck'), 15),
#  (('des', 'levens,', 'seeckerheijt'), 15),
#  (('levens,', 'seeckerheijt', 'des'), 15),
#  (('ofte', 'als', 'codicille,'), 15),
#  (('off', 'andersints,', 'soo'), 15),
#  (('andersints,', 'soo', 'die'), 15),
#  (('soude', 'mogen', 'werden,'), 15),
#  (('mogen', 'werden,', 'die'), 15),
#  (('ende', 'sonder', 'eenige'), 15),
#  (('hebbende', 'en', 'volkomentlijck'), 15),
#  (('ende', 'te', 'niet'), 15),
#  (('off', 'clausulen', 'na'), 15),
#  (('mijns', 'notarij', 'gestaen'), 15),
#  (('daer', 'mede', 'te'), 15),
#  (('van', 'hen', 'beijden'), 15),
#  (('hondert', 'caroli', 'guldens'), 15),
#  (('getuijgen', 'hier', 'toe'), 15),
#  (('winter', 'n.p.', 'ƒ'), 14),
#  (('memorie', 'ende', 'uijtspraecke'), 14),
#  (('gemaeckt', 'ende', 'besproocken'), 14),
#  (('twelck', 'voorsz.', 'staet,'), 14),
#  (('vandien', 'heeft', 'naer'), 14),
#  (('heeft', 'naer', 'christelijcke'), 14),
#  (('overdenckende', 'de', 'broosheijt'), 14),
#  (('haer', 'testament', 'ende'), 14),
#  (('gestaen', 'opte', 'oudesijts'), 14),
#  (('willende', 'alle', 'deselve'), 14),
#  (('krachteloos,', 'ende', 'van'), 14),
#  (('doot', 'deser', 'werelt'), 14),
#  (('deser', 'werelt', 'ontruijmen'), 14),
#  (('mede', 'te', 'mogen'), 14),
#  (('tot', 'dieneijnde', 'allen'), 14),
#  (('onderhouden', 'ende', 'nagekomen,'), 14),
#  (('de', 'klocke', 'bij'), 14),
#  (('versocht', 'ende', 'geroepe'), 14),
#  (('de', 'voorsz.', 'toekomende'), 14),
#  (('drie', 'gul.', 'behoort'), 13),
#  (('mij', 'notario', 'bekent'), 13),
#  (('bleeck', 'wel', 'hebbende'), 13),
#  (('soude', 'mogen', 'sijn'), 13),
#  (('ende', 'gerechticheden', 'egeene'), 13),
#  (('best', 'bestaen', 'magh'), 13),
#  (('dewelcke', 'overdenckende', 'de'), 13),
#  (('testament', 'en', 'uijterste'), 13),
#  (('en', 'uijterste', 'wille'), 13),
#  (('ofte', 'als', 'codicille'), 13),
#  (('notarij', 'gestaen', 'op'), 13),
#  (('jan', 'oorthoorn', 'mede'), 13),
#  (('daer', 'uijt', 'te'), 13),
#  (('wetten', 'ter', 'contrarie'), 13),
#  (('nogh', 'in', 'leven'), 13),
#  (('onses', 'heeren', 'sestienhondert'), 12),
#  (('uijterlijck', 'bleeck', 'wel'), 12),
#  (('recommandatie', 'van', 'ziel'), 12),
#  (('in', 'allen', 'den'), 12),
#  (('geobserveert', 'aldus', 'gedaen'), 12),
#  (('desen', 'gemaeckt', 'haer'), 12),
#  (('best', 'bestaen', 'magh,'), 12),
#  (('off', 'nogh', 'te'), 12),
#  (('alle', 'sodanige', 'generale'), 12),
#  (('te', 'niet', 'doende'), 12),
#  (('niet', 'doende', 'tot'), 12),
#  (('bij', 'haer', 'testatrice'), 12),
#  (('amstelredamme', 'ten', 'huijse'), 12),
#  (('huijse', 'mijns', 'notarij'), 12),
#  (('erffelijck', 'daer', 'mede'), 12),
#  (('te', 'mogen', 'doen'), 12),
#  (('mogen', 'komen', 'te'), 12),
#  (('die', 'sij', 'wilden'), 12),
#  (('getuijgen', 'hier', 'toespecialijcken'), 12),
#  (('verklaren', 'inde', 'quohieren'), 12),
#  (('hare', 'vrije', 'wille'), 12),
#  (('en', 'seeckere', 'getuijgen'), 12),
#  (('clausulen', 'na', 'rechten'), 12),
#  (('niet', 'en', 'mochten'), 12),
#  (('alle', 'voorgaende', 'testamenten,'), 12),
#  (('ure', 'vandien', 'heeft'), 11),
#  (('een', 'nieuws', 'disponerende,'), 11),
#  (('ofte', 'bij', 'voor'), 11),
#  (('geordonneert)', 'die', 'sij'), 11),
#  (('sij', 'wilde', 'als'), 11),
#  (('saecke', 'des', 'doots,'), 11),
#  (('sijn', 'geobserveert', 'aldus'), 11),
#  (('niet', 'te', 'sijn'), 11),
#  (('de', 'klocke', 'halff'), 11),
#  (('hove', 'van', 'holland'), 11),
#  (('te', 'sijn', 'getanxeert'), 11),
#  (('doot,', 'ende', 'te'), 11),
#  (('ten', 'huijse', 'mijns'), 11),
#  (('eenichsints', 'gepasseert', 'off'), 11),
#  (('bij', 'sonder', 'voor'), 11),
#  (('ende', 'nagekomen,', 'alwaert'), 11),
#  (('alsdan', 'nogh', 'in'), 11),
#  (('die', 'gestaen,', 'gelegen,'), 11),
#  (('verstant,', 'memorie,', 'ende'), 11),
#  (('memorie,', 'ende', 'uijtspraecke'), 11),
#  (('broosheijt', 'des', 'levens,'), 11),
#  (('voor', 'mij', 'notario'), 11),
#  (('gedaen', 'binnen', 'amstelredamme,'), 11),
#  (('binnen', 'amstelredamme,', 'ten'), 11),
#  (('bleeck,', 'wel', 'hebbende'), 11),
#  (('behoort', 'tot', 'deese'), 11),
#  (('dat', 'de', 'voorsz.'), 11),
#  (('van', 'hen', 'testateuren'), 11),
#  (('de', 'winter', 'ende'), 11),
#  (('off', 'verleden,', 'willende'), 11),
#  (('een', 'off', 'meer'), 10),
#  (('hare', 'voorsz.', 'kinderen'), 10),
#  (('alsoo', 'geordonneert)', 'die'), 10),
#  (('die', 'sij', 'wilde'), 10),
#  (('mochten', 'sijn', 'geobserveert'), 10),
#  (('de', 'winter,', 'ende'), 10),
#  (('waer', 'die', 'gestaen,'), 10),
#  (('eenichsints', 'metter', 'doot'), 10),
#  (('giste', 'ter', 'saecke'), 10),
#  (('saecke', 'des', 'doots'), 10),
#  (('soude', 'mogen', 'sijn,'), 10),
#  (('en', 'volkomentlijck', 'gebruijckende'), 10),
#  (('gemaeckt', 'haer', 'testament'), 10),
#  (('kostuijmen', 'vereijscht,', 'hierinne'), 10),
#  (('date', 'deses', 'eenichsints'), 10),
#  (('ontruijmen', 'ende', 'naerlaten'), 10),
#  (('wel', 'hebbende', 'ende'), 10),
#  (('sonder', 'voor', 'date'), 10),
#  (('nagekomen,', 'alwaert', 'schoon'), 10),
#  (('ten', 'huijse', 'van'), 10),
#  (('hier', 'toespecialijcken', 'versocht'), 10),
#  (('toespecialijcken', 'versocht', 'ende'), 10),
#  (('met', 'te', 'sijn'), 10),
#  (('als', 'met', 'sijn'), 10),
#  (('heeren', 'sestienhondert', 'ende'), 10),
#  (('sulcx', 'uijterlijck', 'bleeck,'), 10),
#  (('gepasseert', 'off', 'verleden,'), 10),
#  (('actien', 'daer', 'uijt'), 10),
#  (('met', 'gelijcke', 'machte'), 10),
#  (('amstelredamme,', 'ten', 'huijse'), 10),
#  (('christelijcke', 'recommandatie', 'van'), 10),
#  (('sij', 'wilden', 'als'), 10),
#  (('gul.', 'te', 'sijn'), 10),
#  (('hier', 'toe', 'specialijcken'), 10),
#  (('desen', 'gemaeckt', 'haerlieder'), 10),
#  (('vrije', 'wille', 'ende'), 10),
#  (('van', 'jacobus', 'de'), 10),
#  (('verleden,', 'willende', 'alle'), 10),
#  (('in', 'sijn', 'leven'), 9),
#  (('ende', 'gecommitteert', 'mits'), 9),
#  (('daer', 'toe', 'mits'), 9),
#  (('offererende', 'alle', 'sodanige'), 9),
#  (('doots,', 'off', 'andersints,'), 9),
#  (('vast,', 'ende', 'onverbreeckelijck'), 9),
#  (('sulcx', 'uijterlijck', 'bleeckwel'), 9),
#  (('uijterlijck', 'bleeckwel', 'hebbende'), 9),
#  (('des', 'levens', 'seeckerheijt'), 9),
#  (('levens', 'seeckerheijt', 'des'), 9),
#  (('tsij', 'waer', 'die'), 9),
#  (('gelegen', 'off', 'bevonden'), 9),
#  (('bij', 'haer', 'voor'), 9),
#  (('ende', 'nagekomen', 'alwaert'), 9),
#  (('soude', 'willen', 'off'), 9),
#  (('als', 'alsulcx,', 'ofte'), 9),
#  (('alsulcx,', 'ofte', 'als'), 9),
#  (('opte', 'oudesijts', 'voorburghwal'), 9),
#  (('deses', 'eenichsints', 'gepasseert'), 9),
#  (('ende', 'genommeert,', 'soo'), 9),
#  (('overlijden', 'van', 'iemand'), 9),
#  (('als', 'met', 'haer'), 9),
#  (('de', 'klocke', 'over'), 9),
#  (('off', 'bij', 'sonder'), 9),
#  (('allen', 'den', 'goederen,'), 9),
#  (('codicillen,', 'en', 'alle'), 9),
#  (('met', 'sijn', 'off'), 9),
#  (('sestienhondert', 'ende', 'tnegentigh,'), 9),
#  (('de', 'winter,', 'binnen'), 9),
#  (('van', 'ziel', 'en'), 9),
#  (('doots,', 'off', 'andersints'), 9),
#  (('huijsemijns', 'notarij', 'gestaen'), 9),
#  (('van', 'jan', 'bollaert'), 9),
#  (('van', 'uijterste', 'willems'), 9),
#  (('voort', 'met', 'haer'), 9),
#  (('mij', 'notario', 'en'), 9),
#  (('voor', 'eenige', 'actien'), 9),
#  (('geheel', 'ende', 'sonder'), 9),
#  (('penningh', 'met', 'te'), 9),
#  (('van', 'allen', 'den'), 9),
#  (('geliefte,', 'als', 'met'), 9),
#  (('naer', 'christelijcke', 'recommandatie'), 9),
#  (('vijftigh', 'caroli', 'guldens'), 9),
#  (('off', 'bij', 'sijn'), 9),
#  (('ontruijmen', 'en', 'naerlaten'), 9),
#  (('jacobus', 'de', 'winter'), 9),
#  (('ende', 'erffelijck', 'daer'), 9),
#  (('de', 'welcke', 'overdenckende'), 8),
#  (('welcke', 'overdenckende', 'de'), 8),
#  (('seeckerheijt', 'des', 'doots'), 8),
#  (('ende', 'te', 'met'), 8),
#  (('toe', 'mits', 'desen'), 8),
#  (('ende', 'waer', 'op'), 8),
#  (('waer', 'op', 'sij'), 8),
#  (('sal', 'komen', 'te'), 8),
#  (('winter,', 'ende', 'dirck'), 8),
#  (('verstant,', 'memorie', 'ende'), 8),
#  (('actien,', 'crediten,', 'ende'), 8),
#  (('off', 'bij', 'haer'), 8),
#  (('als', 'codicille', 'giste'), 8),
#  (('vast', 'ende', 'onverbreeckelijck'), 8),
#  (('onderhouden', 'ende', 'nagekomen'), 8),
#  (('gestaen', 'op', 'te'), 8),
#  (('voor', 'eenige', 'hoedanige'), 8),
#  (('van', 'dese', 'hare'), 8),
#  (('sodanige', 'generale', 'ende'), 8),
#  (('oorthoorn', 'mede', 'nots.'), 8),
#  (('mede', 'nots.', 'bij'), 8),
#  (('nots.', 'bij', 'den'), 8),
#  (('ende', 'dirck', 'oorgeest'), 8),
#  (('werelt', 'ontruijmen', 'ende'), 8),
#  (('van', 'iemand', 'van'), 8),
#  (('voorsz.', 'staet', 'verklaerde'), 8),
#  (('hebbende', 'ende', 'volkomentlijck'), 8),
#  (('dat', 'de', 'langstlevenden'), 8),
#  (('deroguerende', 'tot', 'dieneijnde'), 8),
#  (('magh,', 'vast,', 'ende'), 8),
#  (('int', 'minste', 'nogh'), 8),
#  (('nagekomen', 'alwaert', 'schoon'), 8),
#  (('jacob', 'de', 'winter,'), 8),
#  (('sijn', 'off', 'haer'), 8),
#  (('bestaen', 'magh', 'vast'), 8),
#  (('nogh', 'te', 'maecken,'), 8),
#  (('te', 'maecken,', 'off'), 8),
#  (('int', 'geheel', 'ende'), 8),
#  (('en', 'wetten', 'ter'), 8),
#  (('hierinne', 'niet', 'en'), 8),
#  (('op', 'saturdagh', 'den'), 8),
#  (('uijterlijck', 'bleeck,', 'wel'), 8),
#  (('met', 'konsent', 'als'), 8),
#  (('wilde', 'als', 'alsulcx'), 8),
#  (('magh', 'vast', 'ende'), 8),
#  (('doots', 'off', 'andersints'), 8),
#  (('ende', 'van', 'onwaerden'), 8),
#  (('notario', 'bekent,', 'gesont'), 8),
#  (('bekent,', 'gesont', 'van'), 8),
#  (('crediten,', 'ende', 'gerechticheden'), 8),
#  (('nogh', 'sal', 'mogen'), 8),
#  (('duijsent', 'caroli', 'guldens'), 8),
#  (('een', 'nieuws', 'disponerende'), 8),
#  (('en', 'goederen', 'is'), 8),
#  (('gemaeckt', 'haerlieder', 'testament'), 8),
#  (('j:de', 'winter', 'n.p'), 8),
#  (('toe', 'specialijcken', 'versocht'), 8),
#  (('bij', 'sijn', 'voor'), 8),
#  (('ende', 'dit', 'alles'), 8),
#  (('van', 'hen', 'testateuren,'), 8),
#  (('presentie', 'van', 'jacobus'), 8),
#  (('uren', 'compareerde', 'voor'), 7),
#  (('gebruijckende', 'de', 'welcke'), 7),
#  (("d'onsekere", 'ure', 'vandien'), 7),
#  (('soo', 'volcht', 'als'), 7),
#  (('mits', 'desen', 'gevende'), 7),
#  (('off', 'gesagh', 'in'), 7),
#  (('allen', 'rechten', 'ende'), 7),
#  (('voorsz.', 'staet,', 'verklaerde'), 7),
#  (('staet,', 'verklaerde', 'sij'), 7),
#  (('te', 'wesen', 'haer'), 7),
#  (('wesen', 'haer', 'testament'), 7),
#  (('descendenten', 'bij', 'plaets'), 7),
#  (('sij', 'testatrice', 'tot'), 7),
#  (('tot', 'executeurs', 'van'), 7),
#  (('magh', 'vast,', 'ende'), 7),
#  (('off', 'kostuijmen', 'vereijscht'), 7),
#  (('voorburghwal', 'bij', 'de'), 7),
#  (('bleeckwel', 'hebbende', 'en'), 7),
#  (('werden,', 'die', 'sij'), 7),
#  (('codicille', 'giste', 'ter'), 7),
#  (('oudesijts', 'voorburghwal', 'bijde'), 7),
#  (('mogen', 'aengesproocken,', 'off'), 7),
#  (('verklaerde', 'sij', 'testatrice'), 7),
#  (('op', 'donderdagh', 'den'), 7),
#  (('des', 'doots,', 'en'), 7),
#  (('uijterste', 'willens', 'dispositien,'), 7),
#  (('doots', 'off', 'andersints,'), 7),
#  (('net', 'en', 'mochten'), 7),
#  (('bij', 'den', 'hove'), 7),
#  (('den', 'hove', 'van'), 7),
#  (('in', 'alle', 'hare'), 7),
#  (('genommeert,', 'soo', 'sij'), 7),
#  (('haer', 'vrije', 'eijgen'), 7),
#  (('ende', 'naerlaten', 'sal'), 7),
#  (('soude', 'mogen', 'komen'), 7),
#  (('dieneijnde', 'allen', 'rechten'), 7),
#  (('namebes', 'heeren', 'amen'), 7),
#  (('ende', 'tnegentigh', 'op'), 7),
#  (('volkomentlijck', 'gebruijckende', 'dewelcke'), 7),
#  (('van', 'der', 'geboorte'), 7),
#  (('jan', 'bollaert', 'ende'), 7),
#  (('des', 'doots', 'ende'), 7),
#  (('ende', 'besproocken', 'mits'), 7),
#  (('soude', 'mogen', 'werden'), 7),
#  (('notario', 'en', 'seeckere'), 7),
#  (('gecommitteert', 'mits', 'desen'), 7),
#  (('winter,', 'binnen', 'amstelredamme'), 7),
#  (('ende', 'dat', 'voor'), 7),
#  (('soo', 'voorgaende', 'als'), 7),
#  (('te', 'sijn', 'getauxeert'), 7),
#  (('vande', 'langstlevenden', 'van'), 7),
#  (('als', 'off', 'het'), 7),
#  (('ende', 'dat', 'onder'), 7),
#  (('eenige', 'actien', 'daer'), 7),
#  (('sal', 'gehouden', 'sijn'), 7),
#  (('actien,', 'crediten', 'ende'), 7),
#  (('eeuwelijck', 'ende', 'erffelijck'), 7),
#  (('haer', 'na', 'rechte'), 7),
#  (('gestelt', 'ende', 'genommeert'), 7),
#  (('voorsz.', 'toekomende', 'echteluijden'), 7),
#  (('en', 'offererende', 'alle'), 7),
#  (('specialijcken', 'versocht', 'ende'), 7),
#  (('bij', 'plaets', 'vullinge,'), 7),
#  (('portie', 'haer', 'na'), 7),
#  (('en', 'bundigh', 'sal'), 7),
#  (('voor', 'notaris', 'en'), 7),
#  (('die', 'hij', 'wilde'), 7),
#  (('hij', 'wilde', 'als'), 7),
#  (('int', 'bij', 'sonder'), 7),
#  (('werelt', 'ontruijmen', 'en'), 7),
#  (('uijt', 'te', 'keeren'), 7),
#  (('dogh', 'andersints', 'hare'), 6),
#  (('verstant', 'memorie', 'ende'), 6),
#  (('de', 'broofheijt', 'des'), 6),
#  (('te', 'met', 'doende'), 6),
#  (('gestelt,', 'ende', 'gecommitteert'), 6),
#  (('voorsz.', 'kinderen', 'en'), 6),
#  (('oock', 'soude', 'mogen'), 6),
#  (('van', 'hare', 'voorsz.'), 6),
#  (('gerechticheden', 'egeene', 'uijtgesondert'), 6),
#  (('die', 'sij', 'testatrice'), 6),
#  (('wijders', 'metter', 'doot'), 6),
#  (('metter', 'doot', 'sal'), 6),
#  (('tot', 'op', 'den'), 6),
#  (('executeurs', 'van', 'dese'), 6),
#  (('penningh', 'niet', 'te'), 6),
#  (('en', 'uijterste', 'wille,'), 6),
#  (('gestaen,', 'gelegen', 'off'), 6),
#  (('geinstitueert,', 'gestelt,', 'ende'), 6),
#  (('magh,', 'vast', 'ende'), 6),
#  (('sij', 'testatrice,', 'dat'), 6),
#  (('van', 'hare', 'testatrices'), 6),
#  (('sullen', 'mogen', 'aengesproocken,'), 6),
#  (('gemaeckt', 'off', 'nogh'), 6),
#  (('dese', 'hare', 'uijterste'), 6),
#  (('rechten,', 'ende', 'in'), 6),
#  (('broosheijt', 'des', 'levens'), 6),
#  (('resommandatie', 'van', 'ziel'), 6),
#  (('generalijcken', 'alle', 'andere'), 6),
#  (('willens', 'dispositien,', 'bij'), 6),
#  (('hierinne', 'net', 'en'), 6),
#  (('testatrice', 'voor', 'date'), 6),
#  (('gestelt,', 'ende', 'genommeert,'), 6),
#  (('ter', 'werelt', 'iets'), 6),
#  (('tot', 'deese', 'annexe'), 6),
#  (('annexe', 'testamente', 'van'), 6),
#  (('residerende', 'openbaer', 'nots.'), 6),
#  (('ende', "d'onsekere", 'ure'), 6),
#  (('vandien', 'hebben', 'naer'), 6),
#  (('hebben', 'naer', 'christelijcke'), 6),
#  (('willens', 'dispositien', 'bij'), 6),
#  (('disponerende,', 'hebben', 'sij'), 6),
#  (('hebben', 'sij', 'testateuren'), 6),
#  (('off', 'kinderen,', 'die'), 6),
#  (('tot', 'regent', 'over'), 6),
#  (('ter', 'contrarie', 'dicterende'), 6),
#  (('voorsz.', 'staet', 'verklaerden'), 6),
#  (('staet', 'verklaerden', 'sij'), 6),
#  (('met', 'off', 'sonder'), 6),
#  (('voor', 'soo', 'veel'), 6),
#  (('van', 'deser', 'stadt'), 6),
#  (('bollaert', 'ende', 'dirck'), 6),
#  (('ende', 'dirck', 'dorgeest'), 6),
#  (('annexe', 'testament', 'van'), 6),
#  (('somme', 'van', 'eenhondert'), 6),
#  (('voorts', 'heeft', 'sij'), 6),
#  (('een', 'somme', 'van'), 6),
#  (('mits', 'desen', 'de'), 6),
#  (('na', 'rechten', 'ende'), 6),
#  (('rechten', 'ende', 'in'), 6),
#  (('ter', 'contrarie', 'dicterende,'), 6),
#  (('vereijscht,', 'hierinne', 'niet'), 6),
#  (('ende', 'dirck', 'dorgeest,'), 6),
#  (('savonts', 'de', 'klocke'), 6),
#  (('nogh', 'maecken', 'nogh'), 6),
#  (('maecken', 'nogh', 'geven'), 6),
#  (('nogh', 'geven', 'eenigen'), 6),
#  (('geven', 'eenigen', 'inventaris'), 6),
#  (('en', 'komende', 'deselve'), 6),
#  (('actien,', 'ende', 'gerechticheden'), 6),
#  (('gehouden', 'sijn,', 'voort'), 6),
#  (('buijten', 'de', 'weeskamer'), 6),
#  (('de', 'weeskamer', 'als'), 6),
#  (('vaders', 'off', 'moeders'), 6),
#  (('als', 'de', 'langstlevenden'), 6),
#  (('desen', 'stellen', 'tot'), 6),
#  (('off', 'na', 'dat'), 6),
#  (('levenden', 'van', 'hen'), 6),
#  (('deselve', 'kinderen', 'met'), 6),
#  (('kinderen', 'met', 'konsent'), 6),
#  (('vorstant', 'memorie', 'ende'), 6),
#  (('van', 'deser', 'stad'), 6),
#  (('onder', 'de', 'vierduijsent'), 6),
#  (('ende', 'genommeert', 'soo'), 6),
#  (('als', 'off', 'deselve'), 6),
#  (('woonachtigh', 'binnen', 'deser'), 6),
#  (('ziel', 'ende', 'lichaem'), 6),
#  (('haer', 'testatrice', 'voor'), 6),
#  (('nieuws', 'disponerende', 'heeft'), 6),
#  (('sal', 'mogen', 'komen'), 6),
#  (('dat', 'het', 'selvige'), 6),
#  (('off', 'het', 'in'), 6),
#  (('in', 'desen', 'geschreven'), 6),
#  (('soo', 'deselve', 'alsdan'), 6),
#  (('dat', 'onder', 'de'), 6),
#  (('schulden,', 'lasten,', 'off'), 6),
#  (('maecken,', 'off', 'voor'), 6),
#  (('tot', 'een', 'ander'), 6),
#  (('haer', 'voor', 'overlijden'), 6),
#  (('kinderen', 'en', 'descendenten'), 6),
#  (('haerlieder', 'verstant,', 'memorie,'), 6),
#  (('haerlieder', 'testament', 'ende'), 6),
#  (('gemaeckt', 'sijn', 'testament'), 6),
#  (('sijn', 'testament', 'ende'), 6),
#  (('ende', 'hier', 'toe'), 6),
#  (('hier', 'na', 'nogh'), 6),
#  (('codicillen', 'en', 'alle'), 6),
#  (('gehouden', 'te', 'sijn'), 6),
#  (('mits', 'desen', 'wel'), 6),
#  (('sal', 'gelieven', 'te'), 6),
#  (('van', 'vijftigh', 'caroli'), 6),
#  (('snaniddaghs', 'de', 'klocke'), 6),
#  (('en', 'naerlaten', 'sal'), 6),
#  (('te', 'mogen', 'doen,'), 6),
#  (('jan', 'bollaert,', 'ende'), 6),
#  (('tot', 'vooghden', 'over'), 6),
#  (('jan', 'jacobsz', 'vander'), 6),
#  (('tnegentigh,', 'op', 'saturdagh'), 6),
#  (('bij', 'de', 'voorsz.'), 6),
#  (('ende', 'geliefte,', 'als'), 6),
#  (('getanxeert', 'j:de', 'winter'), 5),
#  (('volkomentlijck', 'gebruijckende', 'de'), 5),
#  (('alle', 'voorgaende', 'testamenten'), 5),
#  (('nieuws', 'disponerende,', 'heeft'), 5),
#  (('disponerende,', 'heeft', 'sij'), 5),
#  (('ende', 'soo', 'volcht'), 5),
#  (('als', 'henlieden', 'na'), 5),
#  (('omme', 'tallen', 'tijden'), 5),
#  (('tijden', 'een', 'off'), 5),
#  (('van', 'deser', 'stad,'), 5),
#  (('in', 'haren', 'boedel'), 5),
#  (('ende', 'wetten', 'ter'), 5),
#  (('caroli', 'guldens', 'eens'), 5),
#  (('doot', 'sal', 'komen'), 5),
#  (('en', 'wilde', 'sij'), 5),
#  (('in', 'reguarde', 'vande'), 5),
#  (('te', 'mogen', 'werden,'), 5),
#  (('bestaen', 'magh', 'vast,'), 5),
#  (('met', 'en', 'mochten'), 5),
#  (('testatrice', 'verklaert', 'inde'), 5),
#  (('dochter', 'van', 'wijlen'), 5),
#  (('ende', 'hare', 'verstant,'), 5),
#  (('testatrice', 'in', 'alle'), 5),
#  (('die', 'gestaen,', 'gelegen'), 5),
#  (('naerlaten', 'sal,', 'tot'), 5),
#  (('bestaen', 'magh,', 'vast'), 5),
#  (('schoor', 'dat', 'alle'), 5),
#  (('armsbrugh.', 'ter', 'presentie'), 5),
#  (('klercken,', 'gelooffwaerdige', 'getuijgen'), 5),
#  (('soo', 'wilde', 'sij'), 5),
#  (('van', 'off', 'voor'), 5),
#  (('rede', 'gemaeckt', 'off'), 5),
#  (('na', 'rechten,', 'ende'), 5),
#  (('sijnde', 'binnen', 'deser'), 5),
#  (('voort', 'aengaen', 'van'), 5),
#  (('ende', 'voort', 'generalijcken'), 5),
#  (('voort', 'generalijcken', 'alle'), 5),
#  (('ende', 'gerechticheden,', 'egeene'), 5),
#  (('ende', 'naerlaten', 'sal,'), 5),
#  (('met', 'haer', 'vrije'), 5),
#  (('werelt', 'iets', 'uijt'), 5),
#  (('iets', 'uijt', 'te'), 5),
#  (('staet', 'verklaerde', 'sij'), 5),
#  (('doots,', 'ende', "d'onsekere"), 5),
#  (('ure', 'vandien', 'hebben'), 5),
#  (('tesamen,', 'off', 'bij'), 5),
#  (('ende', 'van', 'ouwaerden'), 5),
#  (('nieuws', 'disponerende,', 'hebben'), 5),
#  (('sij', 'testateuren', 'tot'), 5),
#  (('nogh', 'allen', 'den'), 5),
#  (('sullen', 'komen', 'te'), 5),
#  (('crediten', 'ende', 'gerechticheden'), 5),
#  (('des', 'heeren', 'te'), 5),
#  (('te', 'doteren', 'ende'), 5),
#  (('ende', 'tot', 'regent'), 5),
#  (('van', 'haer', 'sterffhuijs,'), 5),
#  (('opper', 'en', 'lager'), 5),
#  (('en', 'alle', 'ander'), 5),
#  (('portie,', 'haer', 'na'), 5),
#  (('alsdan', 'in', 'wesen'), 5),
#  (('die', 'sij', 'bij'), 5),
#  (('sij', 'bij', 'desen'), 5),
#  (('off', 'anderen', 'sal'), 5),
#  (('dit', 'alles', 'tot'), 5),
#  (('vijffentwintigh', 'caroli', 'guldens'), 5),
#  (('soo', 'die', 'bestbestaen'), 5),
#  (('off', 'hare', 'vrije'), 5),
#  (('off', 'sonder', 'kinderen,'), 5),
#  (('sonder', 'kinderen,', 'tot'), 5),
#  (('kinderen,', 'tot', 'hare'), 5),
#  (('in', 'cas', 'van'), 5),
#  (('met', 'en', 'sal'), 5),
#  (('en', 'sal', 'mogen'), 5),
#  (('sieck', 'te', 'bedde'), 5),
#  (('van', 'vijff', 'hondert'), 5),
#  (('vijff', 'hondert', 'caroli'), 5),
#  (('alle', 'hare', 'testatrices'), 5),
#  (('mogen', 'werden', 'die'), 5),
#  (('institueerde,', 'stelde,', 'ende'), 5),
#  (('gestelt', 'ende', 'gecommitteert'), 5),
#  (('generale', 'ende', 'speciale'), 5),
#  (('dieneijnde', 'allen', 'rechten,'), 5),
#  (('hem', 'off', 'haer'), 5),
#  (('huijse', 'van', 'haer'), 5),
#  (('echteluijden', 'woonachtigh', 'inde'), 5),
#  (('met', 'doende', 'tot'), 5),
#  (('te', 'openen', 'eenigen'), 5),
#  (('eenigen', 'inventaris', 'der'), 5),
#  (("d'langstlevenden", 'van', 'hen'), 5),
#  (('kinderen', 'te', 'onderhouden,'), 5),
#  (('off', 'eenige', 'andere'), 5),
#  (('onder', 'den', 'levenden'), 5),
#  (('ende', 'daer', 'van'), 5),
#  (('sonder', 'dat', 'de'), 5),
#  (('niet', 'sal', 'deselve'), 5),
#  (('te', 'maecken', 'van'), 5),
#  (('in', 'wesen', 'sijnde'), 5),
#  (('dat', 'voor', 'alsulcke'), 5),
#  (('bij', 'desen', 'stellen'), 5),
#  (('voorgaende', 'als', 'navolgende'), 5),
#  (('gestelt,', 'ende', 'genommeert'), 5),
#  (('te', 'wesen', 'haerlieder'), 5),
#  (('wesen', 'haerlieder', 'respective'), 5),
#  (('haerlieder', 'respective', 'testament'), 5),
#  (('respective', 'testament', 'ende'), 5),
#  (('(uijt', 'eijgen', 'beweginge'), 5),
#  (('wilden', 'als', 'alsulcx'), 5),
#  (('konsent', 'als', 'vooren'), 5),
#  (('op', 'te', 'oude'), 5),
#  (('langst', 'levenden', 'van'), 5),
#  (('en', 'sullen', 'mogen'), 5),
#  (('nogh', 'de', 'somme'), 5),
#  (('holland', 'geadmitteert,', 'ende'), 5),
#  (('geloofswaerdige', 'getuijgen', 'hier'), 5),
#  (('vierduijsent', 'gul.', 'te'), 5),
#  (('nogh', 'meeste', 'te'), 5),
#  (('ende', 'hare', 'voorsz.'), 5),
#  (('als', 'codicille,', 'giste'), 5),
#  (('tnegentigh,', 'op', 'donderdagh'), 5),
#  (('opte', 'oude', 'sijts'), 5),
#  (('gelooffwaerdig', 'getuijgen', 'hier'), 5),
#  (('dispositien', 'bij', 'haer'), 5),
#  (('van', 'onwaerden', 'ende'), 5),
#  (('disponerende', 'heeft', 'sij'), 5),
#  (('gemaeckt,', 'ende', 'besproocken'), 5),
#  (('vordere', 'goederen,', 'roerende,'), 5),
#  (('t', 'sij', 'waer'), 5),
#  (('veranderen,', 'vermeerderen,', 'off'), 5),
#  (('getuijgen)', 'dat', 'het'), 5),
#  (('in', 'allen', 'schijne'), 5),
#  (('allen', 'schijne', 'als'), 5),
#  (('schijne', 'als', 'off'), 5),
#  (('het', 'in', 'desen'), 5),
#  (('desen', 'geschreven', 'stonde,'), 5),
#  (('geschreven', 'stonde,', 'off'), 5),
#  (('en', 'getuijgen', 'gepasseert'), 5),
#  (('uijterste', 'wille', '(uijteijgen'), 5),
#  (('bestaen', 'magh,', 'vast,'), 5),
#  (('te', 'hebben', 'een'), 5),
#  (('hebben', 'een', 'wettelijck'), 5),
#  (('onder', 'de', 'navolgende'), 5),
#  (('lasten,', 'off', 'kommeren'), 5),
#  (('weeskamer', 'als', 'vooren,'), 5),
#  (('somme', 'van', 'vijffhondert'), 5),
#  (('metten', 'anderen', 'geraemt'), 5),
#  (('conditien', 'en', 'voorwaerden'), 5),
#  (('en', 'voorwaerden', 'de'), 5),
#  (('letrus', 'de', 'winter'), 5),
#  (('en', 'descendenten', 'bij'), 5),
#  (('mitsgaders', 'tot', 'vooghden'), 5),
#  (('over', 'hare', 'voorsz.'), 5),
#  (('rechten', 'en', 'wetten'), 5),
#  (('dispositien,', 'bij', 'henlieden'), 5),
#  (('geinstitueert,', 'gestelt', 'ende'), 5),
#  (('winter', 'ende', 'jan'), 5),
#  (('geboorte', 'desselfs', 'onsee'), 5),
#  (('sijn', 'voor', 'overlijden'), 5),
#  (('den', 'off', 'meer'), 5),
#  (('ƒ', 'aldus', 'gedaen'), 5),
#  (('hebben', 'mits', 'desen'), 5),
#  (('notaris', 'en', 'getuijgen'), 5),
#  (('tot', 'sijne', 'eenige'), 5),
#  (('sijne', 'eenige', 'ende'), 5),
#  (('kinderen', 'van', 'sijn'), 5),
#  (('mogen', 'sijn', 'ende'), 5),
#  (('ende', 'dat', 'soo'), 5),
#  (('buijten', 'sluijtende', 'bij'), 5),
#  (('hier', 'toe', 'nogh'), 5),
#  (('gebruijckende', 'dewelcke', 'overdenckende'), 5),
#  (('bij', 'henlieden', 'tesamen'), 5),
#  (('gepasseert', 'off', 'verleden'), 5),
#  (('haer', 'na', 'rechten'), 5),
#  (('alle', 'swelck', 'voorsz.'), 5),
#  (('burghwal', 'bij', 'de'), 5),
#  (('presentie', 'van', 'letrus'), 5),
#  (('van', 'letrus', 'de'), 5),
#  (('voorsz.', 'huijs', 'en'), 5),
#  (('ende', 'jacobus', 'de'), 5),
#  (('wel', 'te', 'passe'), 5),
#  (('voorgaende', 'testamenten,', 'codicillen,'), 5),
#  (('testamenten,', 'codicillen,', 'en'), 5),
#  (('jacobus', 'de', 'winter,'), 5),
#  (('sodanige', 'generale', 'en'), 5),
#  (('off', 'bij', 'voor'), 5),
#  (('vooghden', 'over', 'hare'), 5),
#  (('tot', 'dit', 'annexe'), 5),
#  (('dit', 'annexe', 'testament'), 5),
#  (('haer', 'voorn.', 'man'), 5),
#  (('te', 'maecken,', 'te'), 5),
#  (('ende', 'dirck', 'oorgeest,'), 5),
#  (('dirck', 'oorgeest,', 'klercken'), 5),
#  (('oorgeest,', 'klercken', 'gelooffwaerdige'), 5),
#  (('bollaert,', 'ende', 'dirck'), 5),
#  (('wille', 'ende', 'geliefte,'), 5),
#  (('te', 'sijn', 'aen'), 5),
#  (('alle', 'hare', 'goederen,'), 5),
#  (('van', 'dese', 'testamente'), 5),
#  (('behoort', 'tot', 'dese'), 4),
#  (('sijn', 'getanxeert', 'j:de'), 4),
#  (('heeren:', 'amen', 'inden'), 4),
#  (('weduwe', 'van', 'wijlen'), 4),
#  (('kerck', 'binnen', 'deser'), 4),
#  (('hare', 'verstant', 'memorie'), 4),
#  (('overdenckende', 'de', 'broofheijt'), 4),
#  (('broofheijt', 'des', 'levens,'), 4),
#  (('des', 'doots', 'en'), 4),
#  (('kinderen', 'van', 'hare'), 4),
#  (('tegens', 'den', 'anderen'), 4),
#  (('versocht,', 'gestelt,', 'ende'), 4),
#  (('gecommitteert', 'mits', 'desen,'), 4),
#  (('haer', 'goede', 'bekende'), 4),
#  (('van', 'haer', 'sterffhuijs'), 4),
#  (('als', 'oock', 'mede'), 4),
#  (('met', 'willende', 'dat'), 4),
#  (('willende', 'dat', 'deselve'), 4),
#  (('dat', 'deselve', 'eenigh'), 4),
#  (('gesegh', 'off', 'gesagh'), 4),
#  (('gesagh', 'in', 'haren'), 4),
#  (('haren', 'boedel', 'off'), 4),
#  (('te', 'nemene', 'moeijten'), 4),
#  (('den', 'inhouden', 'van'), 4),
#  (('het', 'oock', 'soude'), 4),
#  (('dat', 'desodanige', 'sal'), 4),
#  (('allen', 'den', 'vordere'), 4),
#  (('te', 'ontruijmen', 'ende'), 4),
#  (('bij', 'plaets', 'vullinge'), 4),
#  (('moeten', 'erven,', 'ende'), 4),
#  (('op', 'den', 'laesten'), 4),
#  (('ende', 'vanden', 'laesten'), 4),
#  (('vanden', 'laesten', 'mede'), 4),
#  (('gealieneert', 'te', 'mogen'), 4),
#  (('mitsgaders', 'tot', 'regenten'), 4),
#  (('uijterste', 'wille', '(uijt'), 4),
#  (('sonder', 'eenige', 'persuasie'), 4),
#  (('eenige', 'persuasie', 'off'), 4),
#  (('off', 'inductie', 'alsoo'), 4),
#  (('openbaer', 'notaris', 'e'), 4),
#  (('hare', 'verstant,', 'memorie'), 4),
#  (('gebruijckende,', 'dewelcke', 'overdenckende'), 4),
#  (('sij', 'testatrice', 'in'), 4),
#  (('sal,', 'tot', 'hare'), 4),
#  (('bijden', 'hove', 'van'), 4),
#  (('ende', 'pieter', 'de'), 4),
#  (('kinderen', 'van', 'haer'), 4),
#  (('wilde', 'sij', 'testatrice,'), 4),
#  (('goederen', 'en', 'middelen'), 4),
#  (('dat', 'deselve', 'vruchten'), 4),
#  (('eenige', 'hoedanige', 'schulden,'), 4),
#  (('hare', 'uijterste', 'wille,'), 4),
#  (('wille,', 'mitsgaders', 'tot'), 4),
#  (('off', 'meer', 'vooghden'), 4),
#  (('eenige', 'vooghdije', 'off'), 4),
#  (('sij', 'testatrice', 'te'), 4),
#  (('testatrice', 'te', 'wesen'), 4),
#  (('openbaer', 'notaris', 'ec'), 4),
#  (('althans', 'sijnde', 'binnen'), 4),
#  (('mij', 'notario', 'bekendt'), 4),
#  (('naer', 'christelijcke', 'resommandatie'), 4),
#  (('christelijcke', 'resommandatie', 'van'), 4),
#  (('tot', 'dieneijnde', 'specialijcken'), 4),
#  (('met', 'haer', 'voorn.'), 4),
#  (('aengaen', 'van', 'hen'), 4),
#  (('des', 'jaers', 'xvic.'), 4),
#  (('wilde', 'als', 'alsulcx,'), 4),
#  (('onderhouden', 'en', 'nagekomen,'), 4),
#  (('oudesijts', 'voorburghwal', 'bij'), 4),
#  (('bij', 'de', 'armsbrugh.'), 4),
#  (('de', 'armsbrugh.', 'ter'), 4),
#  (('gepasseert', 'off', 'verleden.'), 4),
#  (('egeene', 'uijtgesondert', 'tsij'), 4),
#  (('eenige', 'ende', 'universele'), 4),
#  (('mogen', 'doen', 'hare'), 4),
#  (('geliefte', 'als', 'met'), 4),
#  (('bastiaen', 'cornelisz', 'van'), 4),
#  (('dogh', 'beijde', 'haerlieder'), 4),
#  (('van', 'ouwaerden', 'ende'), 4),
#  (('ouwaerden', 'ende', 'op'), 4),
#  (('testateuren', 'tot', 'hare'), 4),
#  (('eenige', 'ende', 'uiversele'), 4),
#  (('en', 'nommeerden', 'mits'), 4),
#  (('kind', 'off', 'kinderen,'), 4),
#  (('sijne', 'off', 'hare'), 4),
#  (('gesamentlijck', 'vermogen', 'te'), 4),
#  (('langstlevenden', 'gehouden', 'sijn,'), 4),
#  (('en', 'klederen', 'te'), 4),
#  (('heeren', 'te', 'onderwijsen,'), 4),
#  (('te', 'onderwijsen,', 'en'), 4),
#  (('in', 'sijne', 'off'), 4),
#  (('en', 'voort', 'alle'), 4),
#  (('voort', 'alle', 'andere'), 4),
#  (('andersints', 'soo', 'de'), 4),
#  (('hondert', 'ende', 'tnegentigh'), 4),
#  (('somme', 'van', 'vijffentwintigh'), 4),
#  (('in', 'handen', 'vande'), 4),
#  (('gestaen', 'op', 'de'), 4),
#  (('der', 'geboorte', 'desselfs'), 4),
#  (('tnegentigh,', 'op', 'vrij'), 4),
#  (('vrij', 'dagh', 'den'), 4),
#  (('alle', 'ander', 'soorten'), 4),
#  (('langstlevenden', 'van', 'jan'), 4),
#  (('willems', 'dispositien,', 'bij'), 4),
#  (('voor', 'dato', 'deses'), 4),
#  (('tot', 'soo', 'lange'), 4),
#  (('op', 'te', 'voeden'), 4),
#  (('een', 'dochter', 'van'), 4),
#  (('somme', 'van', 'een'), 4),
#  (('guldens', 'eens,', 'ende'), 4),
#  (('somme', 'van', 'vijff'), 4),
#  (('sal', 'de', 'voorsz.'), 4),
#  (('ende', 'sullen', 'de'), 4),
#  (('van', 'eenhondert', 'caroli'), 4),
#  (('voor', 'alle', 'deijlinge'), 4),
#  (('soo', 'van', 'linnen,'), 4),
#  (('met', 'haer', 'testatrices'), 4),
#  (('soo', 'sij', 'institueerde,'), 4),
#  (('sij', 'institueerde,', 'stelde,'), 4),
#  (('ende', 'de', 'voorn.'), 4),
#  (('voldaen', 'ende', 'betaelt'), 4),
#  (('als', 'om', 'andere'), 4),
#  (('te', 'hebben', 'mits'), 4),
#  (('de', 'vruchten', 'ende'), 4),
#  (('soo', 'sullen', 'de'), 4),
#  (('allen', 'rechten,', 'en'), 4),
#  (('rechten,', 'en', 'wetten'), 4),
#  (('waerdige', 'getuijgen', 'hier'), 4),
#  (('winter', 'n.p.', 'de'), 4),
#  (('doots,', 'ende', "d'onseeckere"), 4),
#  (('ende', 'alle', 'andere'), 4),
#  (('te', 'onderhouden,', 'op'), 4),
#  (('ende', 'na', 'elcx'), 4),
#  (('mondige', 'jaren', 'off'), 4),
#  (('staet', 'off', 'conditien,'), 4),
#  (('malkanderen,', 'ende', 'sulcx'), 4),
#  (('allen', 'den', 'goederen'), 4),
#  (('ende', 'gerechticheden', 'des'), 4),
#  (('boedels,', 'met', 'oock'), 4),
#  (('deselve', 'goederen', 'en'), 4),
#  (('en', 'anders', 'te'), 4),
#  (('anders', 'te', 'mogen'), 4),
#  (('ende', 'daer', 'mede'), 4),
#  (('daer', 'van', 'disponeren,'), 4),
#  (('van', 'disponeren,', 'gelijck'), 4),
#  (('sal', 'gehouden', 'sijn,'), 4),
#  (('nogh', 'geconstringeert', 'mogen'), 4),
#  (('geconstringeert', 'mogen', 'werden,'), 4),
#  (('kinderen', 'buijten', 'de'), 4),
#  (('off', 'moeders', 'erffenisse'), 4),
#  (('stellen', 'tot', 'eenige'), 4),
#  (('voorsz.', 'kinderen', 'bij'), 4),
#  (('ende', 'genommeert', 'bij'), 4),
#  (('binnen', 'amstelredamme', 'een'), 4),
#  (('te', 'oude', 'sijts'), 4),
#  (('goederen', 'der', 'kinderen,'), 4),
#  (('der', 'kinderen,', 'blijven'), 4),
#  (('als', 'vooren', 'gekomen'), 4),
#  (('vooren', 'gekomen', 'sullen'), 4),
#  (('portie', 'off', 'portien'), 4),
#  (('als', 'vooghden', 'na'), 4),
#  (('van', 'holland', 'geadmitteert,'), 4),
#  (('klercken', 'geloofswaerdige', 'getuijgen'), 4),
#  (('penningh', 'onder', 'de'), 4),
#  (('de', 'vierduijsent', 'gul.'), 4),
#  (('schaep', 'j:de', 'winter'), 4),
#  (('met', 'volle', 'recht'), 4),
#  (('volle', 'recht', 'van'), 4),
#  (('aldus', 'gedaan', 'binnen'), 4),
#  (('op', 'de', 'hoeck'), 4),
#  (('segel', 'van', 'acht'), 4),
#  (('off', 'te', 'doen'), 4),
#  (('soo', 'als', 'deselve'), 4),
#  (('voor', 'alsulcke', 'vooghden'), 4),
#  (('alsulcke', 'vooghden', 'als'), 4),
#  (('vooghden', 'als', 'de'), 4),
#  (('ende', 'genomineert', 'bij'), 4),
#  (('wesen', 'sijnde', 'ende'), 4),
#  (('codicille,', 'giste', 'ter'), 4),
#  (('soo', 'de', 'best'), 4),
#  (('mij', 'notario', 'bekendt,'), 4),
#  (('als', 'alsulcx', '/'), 4),
#  (('gestaen', 'opte', 'oude'), 4),
#  (('oude', 'sijts', 'voorburghwal'), 4),
#  (('bij', 'de', 'armsbrugh'), 4),
#  (('ende', 'jan', 'bollaert'), 4),
#  (('de', 'winter', 'n.p'), 4),
#  (('j:', 'dewinter', 'n.p.'), 4),
#  (('casserende,', 'doot', 'ende'), 4),
#  (('den', 'testamente', 'bij'), 4),
#  (('testamenten,', 'codicillen', 'en'), 4),
#  (('uijterste', 'willens', 'dispositien'), 4),
#  (('den', 'vordere', 'goederen,'), 4),
#  (('gerechticheden', 'egeene', 'uijtgesondert,'), 4),
#  (('sij', 'waer', 'die'), 4),
#  (('gestelt', 'ende', 'genommeert,'), 4),
#  (('overlijden', 'van', 'gemand'), 4),
#  (('van', 'gemand', 'van'), 4),
#  (('eijgenhandt', 'off', 'onderteeckeningh'), 4),
#  (('werden,', 'in', 'allen'), 4),
#  (('off', 'andersints', 'voor'), 4),
#  (('getuijgen', 'gepasseert', 'ware,'), 4),
#  (('somme', 'van', 'tweehondert'), 4),
#  (('van', 'tweehondert', 'caroli'), 4),
#  (('gifte', 'ter', 'saecke'), 4),
#  (('toekomende', 'bruijdegom', 'ter'), 4),
#  (('toekomende', 'bruijdegom,', 'ter'), 4),
#  (('ter', 'eenre.', 'ende'), 4),
#  (('notario', 'als', 'haren'), 4),
#  (('en', 'sal', 'sijn'), 4),
#  (('soo', 'sal', 'de'), 4),
#  (('goederen,', 'actien,', 'ende'), 4),
#  (('ende', 'instrueren,', 'tot'), 4),
#  (('instrueren,', 'tot', 'hare'), 4),
#  (('sal', 'deselve', 'langstlevenden'), 4),
#  (('deselve', 'langstlevenden', 'gehouden'), 4),
#  (('van', 'vijffhondert', 'caroli'), 4),
#  (('tot', 'hare', 'mede'), 4),
#  (('vande', 'voorsz.', 'toekomende'), 4),
#  (('geslooten', 'te', 'hebben'), 4),
#  (('een', 'wettelijck', 'huwelijck'), 4),
#  (('wettelijck', 'huwelijck', 'aen'), 4),
#  (('den', 'goederen,', 'actien'), 4),
#  (('ende', 'tnegentigh,', 'opdinghdagh'), 4),
#  (('tnegentigh,', 'opdinghdagh', 'den'), 4),
#  (('onwaerden', 'ende', 'op'), 4),
#  (('nommeerden', 'mits', 'desen'), 4),
#  (('speciale', 'machte,', 'als'), 4),
#  (('dirck', 'oorgeest', 'klercken'), 4),
#  (('off', 'die', 'alle'), 4),
#  (('op', 'hare', 'testatrices'), 4),
#  (('in', 'prejudicie', 'vandien,'), 4),
#  (('prejudicie', 'vandien,', 'off'), 4),
#  (('desselfs', 'kinderen', 'en'), 4),
#  (('alle', "'tselvige", 'mits'), 4),
#  (("'tselvige", 'mits', 'desen'), 4),
#  (('lichaem', 'mits', 'desen'), 4),
#  (('daermede', 'te', 'mogen'), 4),
#  (('bij', 'maniere', 'van'), 4),
#  (('langstlevende', 'sijnde,', 'sal'), 4),
#  (('voorsz.', 'staet,', 'verklaerden'), 4),
#  (('staet,', 'verklaerden', 'sij'), 4),
#  (('gestaen', 'als', 'vooren,'), 4),
#  ...]

# %%
st = sorted([' '.join(s) for s in tc])

# %%
[t for t in st if t[0:3] == 'te ']
# Out:
# ['te 1ebben gelijck',
#  'te 470 te',
#  'te 5 ii',
#  'te achtervolgen alle',
#  'te achtervolgen voldoen',
#  'te adcumeren en',
#  'te adsmmeren en',
#  'te adsumorei off',
#  'te adsumoren off',
#  "te aenvaerden d'andere",
#  'te aliamentarin in',
#  'te aliementeren en',
#  'te aliementeren, in',
#  'te aliemerter in',
#  'te alimenta ren',
#  'te alimenteren in',
#  'te alimenteren, in',
#  'te alimenterlnj in',
#  'te ampaerteren. mits',
#  'te ander houden',
#  'te ander huwelijck,',
#  'te approberen en',
#  'te approberen ende',
#  'te approberen, ende',
#  'te aprobeen en',
#  'te aproberen ende',
#  'te articiparen, off',
#  'te asproberen e',
#  'te avaerden gevande',
#  'te bchoren, sonder',
#  'te bedde laggen',
#  'te bedde leggende',
#  'te bedde leggende,',
#  'te bedde leggende,/',
#  'te begeven deschel',
#  'te begeven, deselve',
#  'te begeven, desen',
#  'te behoren, alle',
#  'te behoren, elle',
#  'te behoren. alle',
#  'te behorende als',
#  'te behouden, soo',
#  'te beleggen op',
#  'te belevem den',
#  'te bercolijen /',
#  'te bescharmen, dat',
#  'te bespreecken /en',
#  'te besteden, inde',
#  'te bestellen ende',
#  'te betalen besprack',
#  'te betalen ten',
#  'te beter mits',
#  'te bewijsee en',
#  'te bewijsen hinne',
#  'te bewijsen se',
#  'te bewijsen uijtsluijtende',
#  'te bewijsen voor',
#  'te bewoijsen de',
#  'te bij voor',
#  'te bligaen en',
#  'te bligaren in',
#  'te botaen 6de',
#  'te brengen ende',
#  'te brengen, ende',
#  'te brouwen mondigh',
#  'te brouwen/ onon',
#  'te caroen, voor',
#  'te cavoelen, voor',
#  'te cavoren, voor',
#  'te committeren stervende,',
#  'te competeren in',
#  'te consequaem de',
#  'te consisteren mo',
#  'te coorlijdan /',
#  'te croene kapitall',
#  'te crot enige',
#  'te d:trrgeesl wesen',
#  'te dadomen legateren,',
#  'te dasen van',
#  'te declareren, dat',
#  'te dedomneren, legateren,',
#  'te designeren en',
#  'te disponeren,/ voor,',
#  'te dispooneren, te',
#  'te ditpoveren, voor',
#  'te doe ende',
#  'te doeen ende',
#  "te doen 'selvige",
#  'te doen bestellen',
#  'te doen eainge',
#  'te doen eede',
#  'te doen eenige',
#  'te doen ende',
#  'te doen leeren',
#  'te doen off',
#  'te doen sal',
#  'te doen, dessaltselt',
#  'te doen, eenige',
#  'te doen, ende',
#  'te doen, sullln',
#  'te doen, welcke',
#  'te doen. dat',
#  'te doer eenige',
#  'te dogn eenige',
#  'te doteren ende',
#  'te doteren euijtse',
#  'te doteren quijt',
#  'te doteren suijtt',
#  'te doteren, ende',
#  'te doterlij en',
#  'te dotorm ln',
#  'te dragen op',
#  'te dragen vert',
#  'te dragen, ƒ',
#  'te drdonneren legate',
#  'te eacxutoure van',
#  'te ebben voor',
#  'te eenichsints noden',
#  'te eerder met',
#  'te eerder met,',
#  'te eerder niet',
#  'te eligeren deschie',
#  'te eligeren en',
#  'te eligeren ende',
#  'te emploijeren all',
#  'te emploijeren alle',
#  'te en inder',
#  'te ende mallen',
#  'te ender hondeu,',
#  'te enderhouden tam',
#  'te entstalij off',
#  'te erve beuren',
#  'te erve beuren,',
#  'te erve goederen,',
#  'te erven ende',
#  'te erven off',
#  'te excuseren en',
#  'te executeurs sullen',
#  'te fijn getauxeert',
#  'te gaen tot',
#  'te galn tot',
#  'te gebeuren datiemand',
#  'te gebeuren, dat',
#  'te gebluren, dat',
#  'te geeln penng',
#  'te gehrijgen, en',
#  'te gelde te',
#  'te gelden off',
#  'te gelder aren',
#  'te gene deeden,',
#  'te genieten eerlijck',
#  'te genieten) brecken,',
#  'te genieten, de',
#  'te genieten, onder',
#  'te geriten, ende',
#  'te geven, welcke',
#  'te geven,/ oftl',
#  'te gl van',
#  'te goen tot',
#  'te hare eenige',
#  'te hare gemoet',
#  'te hare gemold',
#  'te hatrice dat',
#  'te hebben een',
#  'te hebben en',
#  'te hebben eoor',
#  'te hebben gelijck',
#  'te hebben in',
#  'te hebben mits',
#  'te hebben off',
#  'te hebben sinder',
#  'te hebben te',
#  'te hebben voor',
#  'te hebben voorn',
#  'te hebben, gelijck',
#  'te hebben, sonder',
#  'te hebben, soo',
#  'te hebben, tot',
#  'te hebben, voor',
#  'te hebben. sonder',
#  'te hobben voor',
#  'te houden buijten',
#  'te houden, soo',
#  'te hterven, ende',
#  'te huij maecker',
#  'te ille disponeren,',
#  'te ilterestene henl.',
#  'te item de',
#  'te ke aende',
#  'te kedren ten',
#  'te keer voorsz.',
#  "te keeren 'geenewes,",
#  'te keeren aen',
#  'te keeren de',
#  'te keeren ende',
#  'te keeren jaerlijcx',
#  'te keeren, best',
#  'te keeren. aen',
#  'te kennen, jan',
#  'te kiesene vooght',
#  'te koeren de',
#  'te koerleeren /',
#  'te kom daervooren',
#  'te kontracteren, off',
#  'te kouwen, mandig',
#  'te laten leeren,',
#  'te legateren, bespreecken.',
#  'te libereren en',
#  'te lichten ende',
#  'te licrten en',
#  'te loveren staet',
#  'te luijven ende',
#  'te maecken 2e',
#  'te maecken als',
#  'te maecken of',
#  'te maecken off',
#  'te maecken van',
#  'te maecken, ende',
#  'te maecken, off',
#  'te maecken, te',
#  'te maecken,/ off',
#  'te magen adsimeren',
#  'te maken van',
#  'te malcken passaren',
#  'te malkan, ordonnaen,',
#  'te megen aff',
#  'te met doeade',
#  'te met doende',
#  'te met gedaente',
#  'te miet doende',
#  'te miet doerde',
#  'te moecken off',
#  'te moecken, off',
#  'te mogen adsimeren',
#  'te mogen adsmaeren',
#  'te mogen adsmmeren',
#  'te mogen adsmuuren',
#  'te mogen adsumeren',
#  'te mogen aenleggen,',
#  'te mogen aenleggen,.',
#  'te mogen aenvaelden,',
#  'te mogen aenvaerden',
#  'te mogen anraerden,',
#  'te mogen asumeren',
#  'te mogen da',
#  'te mogen dispoveren',
#  'te mogen doen',
#  'te mogen doen,',
#  'te mogen doon',
#  'te mogen een',
#  'te mogen kiesen',
#  'te mogen kissen',
#  'te mogen kusen',
#  'te mogen renleggen,',
#  'te mogen te',
#  'te mogen verkopen',
#  'te mogen versterven',
#  'te mogen werde',
#  'te mogen werden)',
#  'te mogen werden,',
#  'te mogen werden.',
#  'te mogen werelt',
#  'te mogen, doen',
#  'te mogende aenleggen,',
#  'te mot doende',
#  'te nemen en',
#  'te nemen soo',
#  'te nemen, eerlijcken',
#  'te nemen, ende',
#  'te nemene maeijten',
#  'te nemene mobijten',
#  'te nemene moeijten',
#  'te nep doende',
#  'te net gedaen',
#  'te newene mbeijten',
#  'te niet deede',
#  'te niet doen',
#  'te niet doende',
#  'te niet gedaen',
#  'te niot doende',
#  'te oiptlaijeren, alll',
#  'te ondarijsam /',
#  'te onder handen',
#  'te onderhonden ende',
#  'te onderhonden, opgebrangen,',
#  'te onderhouden ende',
#  'te onderhouden op',
#  'te onderhouden opte.',
#  'te onderhouden, item',
#  'te onderhouden, op',
#  'te onderhouden, optebrengen,',
#  'te onderhoudende item',
#  'te onderwijsen, en',
#  'te ontruijman 6',
#  'te ontruijman dn',
#  'te ontruijmen ende',
#  'te ontruijmig aetertlaten',
#  'te ontstaen off',
#  'te openb. eenigen',
#  'te openen eenigen',
#  'te oplnan lngen',
#  'te opposeren off',
#  'te ordon noren',
#  'te ordonneren legateren',
#  'te ordonneren, legateren,',
#  'te ordonneren, legateren.',
#  'te ordonneren. legaseren,',
#  'te ordoomer broeder',
#  'te orie cluren',
#  'te oude houden,',
#  'te oude sijs',
#  'te oude sijts',
#  'te oudesijts voor',
#  'te oudesijts voorburghwal',
#  'te oudt houden',
#  'te outstaen off',
#  'te out¬ ruijmen',
#  'te ovarlijden) aen',
#  'te over lijdene',
#  'te overbijden, tals',
#  'te overleden, als',
#  'te overleden, sonder',
#  'te overlijden en',
#  'te overlijden op',
#  'te overlijden, als',
#  'te overlijden, op',
#  'te overlijden, sonder',
#  'te overlijden, soo',
#  'te overlijden. dat',
#  'te ovorlijden a',
#  'te ovorlijden, golijck',
#  'te participeren inde',
#  'te participeren off',
#  'te partigh inde',
#  'te passe sijnde,',
#  'te passe zijnde,',
#  "te passeren, 't",
#  'te passeren, als',
#  'te passeren, dat',
#  'te passeren, in',
#  'te passeren, sonder',
#  'te passeren, soo',
#  'te passoren dat',
#  'te pessoen, sullen',
#  'te poechaoff lanneij',
#  'te porse sijnde',
#  'te posseren soo',
#  'te ppretararen tot',
#  'te procederen e',
#  'te procederen voortsheoft',
#  'te procederen, alle',
#  'te procederen, dulcx',
#  'te procederen, ende',
#  'te procideren inde',
#  'te procreeeren ende',
#  'te procreeren ende',
#  'te prolederen, ende',
#  'te prolederen. alle',
#  'te prooederen, alle',
#  'te prose al',
#  'te prosederen alne',
#  'te prosederen voor',
#  'te prosreeeren ende',
#  'te rabban, ende',
#  'te rade vinden',
#  'te rade werden',
#  'te rade wert',
#  'te rade wert,',
#  'te rade wert,/',
#  'te rade worden.',
#  'te raden sal',
#  'te rassal¬ tiee',
#  'te recken eenige',
#  'te regeren en',
#  'te reijcken ende',
#  'te reijcken tot',
#  'te reijcken, de',
#  'te rekenen naetgetal',
#  'te reserveren, maer',
#  'te resteren, aende',
#  'te salcke das',
#  'te salcke dee',
#  'te salcke des',
#  'te samen, off',
#  'te saveren voor',
#  'te scheijdinge als',
#  'te schoeel van',
#  'te seeren, ses',
#  'te setten met',
#  'te setten, soo',
#  'te sien getauveert',
#  'te sijn aen',
#  'te sijn beswaert',
#  'te sijn daer',
#  'te sijn dinez',
#  'te sijn ee',
#  'te sijn gequatiseert',
#  'te sijn gequotiseert',
#  'te sijn getaaxeert',
#  'te sijn getaexeert',
#  'te sijn getaixeert',
#  'te sijn getamxer',
#  'te sijn getangeert',
#  'te sijn getanxeert',
#  'te sijn getaupen',
#  'te sijn getauxee',
#  'te sijn getauxeec',
#  'te sijn getauxeelt',
#  'te sijn getauxeert',
#  'te sijn getaxeert',
#  'te sijn getuij',
#  'te sijn van',
#  'te sijn, ende',
#  'te sijn, heeft',
#  'te sijn, inne',
#  'te sijn, willende',
#  'te sijn,/ gelijck',
#  'te sijt getauxeert',
#  'te son gelijck',
#  'te spenderen den',
#  'te sppecifiaarei uijt',
#  'te staen d',
#  'te stamen, sonder',
#  'te statevan aen',
#  'te stellen bchoorlijcke',
#  'te stellen off',
#  'te sterven /',
#  'te sterven en',
#  'te sterven int',
#  'te sterven oude',
#  'te sterven, ende',
#  'te sterven, sonder',
#  'te storvan mot',
#  'te sul juste',
#  'te sullen achtervolgen',
#  'te sullen achtor',
#  'te sullen affenteren',
#  'te sullen attenteren',
#  'te sullen geven,',
#  'te sullen tesseren,',
#  'te sullen vatrecken,',
#  'te sullen voltrooken.',
#  'te sullen vostrecken',
#  'te susporti de',
#  'te tallen, anmede',
#  'te tamen off',
#  'te teelen ende',
#  'te temaecken, sulcx',
#  'te tot stervens',
#  'te touwen mondige',
#  'te touwen, moudig',
#  'te trecken met',
#  'te treden instituerende',
#  'te tromoen, off',
#  'te trouoen, mondige',
#  'te trouven mondige',
#  'te trouwe mandige',
#  'te trouwen mmondige',
#  'te trouwen off',
#  'te trouwen, mondige',
#  'te twee stoffers',
#  'te uijt wat',
#  'te vallen dat',
#  'te vallen off',
#  'te vallen, gestelt',
#  'te vallen, off',
#  'te vallen, versocht,',
#  'te van jemand',
#  'te varen naer',
#  'te verde in',
#  'te verkiesa gevende',
#  'te verkiesen de',
#  'te verkiesen, dat',
#  'te verkiesen, devende',
#  'te verkiesen, gevende',
#  'te verkopen en',
#  'te verkopen ende',
#  'te verkusen, gevende',
#  'te versoecken, t',
#  'te verteeren, ende',
#  'te vesl haocklder',
#  'te voeden 1',
#  'te voeden en',
#  'te volden, ende',
#  'te volgen ende',
#  'te voorn op,',
#  'te vrede sullen',
#  'te vreden tehouden',
#  'te vreede sullen',
#  'te waslen haerlieden',
#  'te weesen haer',
#  'te weesen haerlieder',
#  'te weginge en',
#  'te werden ende',
#  'te werden mitsgehouden',
#  'te werden soo',
#  'te werden ten',
#  'te werden tot',
#  'te werden, de',
#  'te wesen haar',
#  'te wesen hae',
#  'te wesen haer',
#  'te wesen haerliede',
#  'te wesen haerlieder',
#  'te wesen haerliedere',
#  'te wesen harrice',
#  'te wesen sij',
#  'te wesen sijn',
#  'te weta dat',
#  'te weten bij',
#  'te weten hij',
#  "te wetene d'eene",
#  'te wetene hij']

# %%
scan = scans[0]
lines = scan.get_lines()
for l in lines:
    c = l.coords
    print(f'({c.x},{c.y})-({c.x+c.w},{c.y+c.h}) : {l.text} {l.baseline}')
# Out:
# (1681,139)-(1732,242) : ƒ Baseline(points="1691,228 1707,231")
# (1543,949)-(1589,1142) : None Baseline(points="1551,1146 1581,1146")
# (1176,936)-(1375,1191) : ƒ Baseline(points="1187,1151 1212,1154 1238,1155 1264,1154 1289,1153 1315,1152 1341,1151 1367,1151")
# (938,956)-(1073,1198) : ƒ Baseline(points="963,1164 995,1152 1027,1152 1059,1149")
# (436,2166)-(1722,2405) : DSamentele Baseline(points="444,2333 507,2336 570,2339 633,2343 697,2346 760,2350 823,2354 887,2357 950,2361 1013,2364 1077,2366 1140,2369 1203,2370 1266,2372 1330,2373 1393,2373 1456,2373 1520,2371 1583,2369 1646,2366 1710,2363")
# (1456,2416)-(1693,2572) : e Baseline(points="1464,2532 1491,2532 1518,2533 1545,2535 1572,2538 1599,2539 1626,2541 1653,2541 1680,2541")
# (1185,2619)-(1259,2735) : d Baseline(points="1193,2720 1242,2724")
# (1077,2954)-(1741,3135) : J:de Winter N.P. Baseline(points="1085,3071 1117,3073 1149,3076 1182,3078 1214,3080 1247,3081 1279,3083 1311,3083 1344,3084 1376,3084 1409,3084 1441,3084 1473,3084 1506,3083 1538,3083 1571,3082 1603,3081 1635,3081 1668,3080 1700,3080 1733,3080")

# %%
print(c.x)
print(c.y)
print(c.w)
print(c.h)
# Out:
# 1077
# 2954
# 664
# 181
